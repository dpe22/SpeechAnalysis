# %% [markdown]
# This is the 1st part of my mini series relating to Detecting Respiratory Disease with the use of Respiratory Audio (breathing sounds). For this kernel, we're only going to slice each audio file into subslices which is defined by the txt files.
#
# - Part 2: [Split into train and test](https://www.kaggle.com/danaelisanicolas/cnn-part-2-split-to-train-and-test)
# - Part 3: [Create spectrogram images from audio](https://www.kaggle.com/danaelisanicolas/cnn-part-3-create-spectrogram-images)
# - Part 4: [Create and train a VGG16 model with the spec images](https://www.kaggle.com/danaelisanicolas/cnn-part-4-training-and-modelling-with-vgg16)
#
# Let's start.
#
# Here you'll see that i'm importing librosa and soundfile which are python packages that deals with audio files.
# * [Librosa](https://librosa.github.io/librosa/)
# * [Soundfile](https://pysoundfile.readthedocs.io/en/latest/)
#
# Boxplot_stats will be used later to see outliers. More of this later

# %%
import pandas as pd
import numpy as np
import math

import librosa as lb # https://librosa.github.io/librosa/
import soundfile as sf # https://pysoundfile.readthedocs.io/en/latest/

import os

import matplotlib.pyplot as plt
from matplotlib.cbook import boxplot_stats

# %% [markdown]
# I had to look first where the audio and text files are by using !ls

# %%
# !ls ../input/respiratory-sound-database/respiratory_sound_database/Respiratory_Sound_Database
# Out:
# audio_and_txt_files	  filename_format.txt
# filename_differences.txt  patient_diagnosis.csv

# %% [markdown]
# Load the patient diagnosis file first and check all the unique diagnosis we have in our data.
#
# This is necessary in how we will sort our output later.

# %%
#load patient diagnosis.csv

diag_csv = '../input/respiratory-sound-database/respiratory_sound_database/Respiratory_Sound_Database/patient_diagnosis.csv'
diagnosis = pd.read_csv(diag_csv, names=['pId', 'diagnosis'])
diagnosis.head()
# Out:
#    pId diagnosis
# 0  101      URTI
# 1  102   Healthy
# 2  103    Asthma
# 3  104      COPD
# 4  105      URTI

# %%
ds = diagnosis['diagnosis'].unique()
ds
# Out:
# array(['URTI', 'Healthy', 'Asthma', 'COPD', 'LRTI', 'Bronchiectasis',
#        'Pneumonia', 'Bronchiolitis'], dtype=object)

# %% [markdown]
# Next we will need to read all the unique files in our dataset. This is done by using the os.listdir function with the condition of checking only .txt files.
#
# Note: We can also use the condition to check .wav files. Eitherway we'll just check all unique files. Condition is needed because if we're checking all kinds of files, we may get replicates. Our dataset consists of .txt and its equivalent .wav files.

# %%
#get all text files
audio_text_loc = '../input/respiratory-sound-database/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files'
files = [s.split('.')[0] for s in os.listdir(path = audio_text_loc) if '.txt' in s]
files
# Out:
# ['160_1b3_Al_mc_AKGC417L',
#  '146_2b2_Pl_mc_AKGC417L',
#  '130_2b2_Ll_mc_AKGC417L',
#  '159_1b1_Pr_sc_Meditron',
#  '130_1p4_Tc_mc_AKGC417L',
#  '186_2b2_Tc_mc_AKGC417L',
#  '178_1b2_Pr_mc_AKGC417L',
#  '158_1p4_Lr_mc_AKGC417L',
#  '138_2p2_Lr_mc_AKGC417L',
#  '130_1p3_Pr_mc_AKGC417L',
#  '158_1p4_Tc_mc_AKGC417L',
#  '151_3p2_Lr_mc_AKGC417L',
#  '170_2b2_Pl_mc_AKGC417L',
#  '209_1b1_Tc_sc_Meditron',
#  '122_2b3_Al_mc_LittC2SE',
#  '160_1b3_Tc_mc_AKGC417L',
#  '130_1p2_Ar_mc_AKGC417L',
#  '160_1b3_Lr_mc_AKGC417L',
#  '170_2b2_Al_mc_AKGC417L',
#  '110_1p1_Pr_sc_Meditron',
#  '172_1b3_Ll_mc_AKGC417L',
#  '193_7b3_Pr_mc_AKGC417L',
#  '156_2b3_Al_mc_AKGC417L',
#  '178_1b3_Pr_mc_AKGC417L',
#  '124_1b1_Ar_sc_Litt3200',
#  '130_3b4_Lr_mc_AKGC417L',
#  '146_8p3_Lr_mc_AKGC417L',
#  '205_1b3_Ll_mc_AKGC417L',
#  '193_1b2_Ll_mc_AKGC417L',
#  '107_2b5_Al_mc_AKGC417L',
#  '162_1b2_Lr_mc_AKGC417L',
#  '156_2b3_Ll_mc_AKGC417L',
#  '172_2b5_Pr_mc_AKGC417L',
#  '118_1b1_Ll_sc_Litt3200',
#  '107_2b5_Pl_mc_AKGC417L',
#  '110_1b1_Pr_sc_Meditron',
#  '163_8b3_Pl_mc_AKGC417L',
#  '197_1b1_Tc_sc_Meditron',
#  '122_2b3_Ar_mc_LittC2SE',
#  '147_1b2_Tc_mc_AKGC417L',
#  '158_2p3_Tc_mc_AKGC417L',
#  '177_1b2_Tc_mc_AKGC417L',
#  '113_1b1_Pl_sc_Litt3200',
#  '151_2p4_Lr_mc_AKGC417L',
#  '130_2b3_Ll_mc_AKGC417L',
#  '170_2b2_Tc_mc_AKGC417L',
#  '157_1b1_Al_sc_Meditron',
#  '164_1b1_Ll_sc_Meditron',
#  '192_2b3_Al_mc_LittC2SE',
#  '222_1b1_Pr_sc_Meditron',
#  '170_1b3_Ar_mc_AKGC417L',
#  '220_1b2_Al_mc_LittC2SE',
#  '163_8b3_Ll_mc_AKGC417L',
#  '178_1b3_Al_mc_AKGC417L',
#  '158_1p3_Pl_mc_AKGC417L',
#  '198_1b5_Pl_mc_AKGC417L',
#  '174_1p2_Ll_mc_AKGC417L',
#  '221_2b3_Pr_mc_LittC2SE',
#  '163_8b3_Pr_mc_AKGC417L',
#  '200_2p2_Lr_mc_AKGC417L',
#  '130_1p4_Lr_mc_AKGC417L',
#  '178_1b3_Tc_mc_AKGC417L',
#  '160_1b2_Pr_mc_AKGC417L',
#  '130_1p4_Pr_mc_AKGC417L',
#  '172_1b4_Ll_mc_AKGC417L',
#  '200_3p4_Ar_mc_AKGC417L',
#  '174_1p4_Lr_mc_AKGC417L',
#  '186_2b4_Pr_mc_AKGC417L',
#  '130_2p5_Tc_mc_AKGC417L',
#  '205_2b3_Ll_mc_AKGC417L',
#  '119_1b1_Ar_sc_Meditron',
#  '127_1b1_Ar_sc_Meditron',
#  '176_1b3_Tc_mc_AKGC417L',
#  '186_2b4_Tc_mc_AKGC417L',
#  '172_1b5_Tc_mc_AKGC417L',
#  '110_1p1_Al_sc_Meditron',
#  '138_2p2_Pl_mc_AKGC417L',
#  '186_2b3_Al_mc_AKGC417L',
#  '158_2p3_Lr_mc_AKGC417L',
#  '145_3b4_Pl_mc_AKGC417L',
#  '130_2b4_Ll_mc_AKGC417L',
#  '199_2b1_Ll_mc_LittC2SE',
#  '221_2b2_Lr_mc_LittC2SE',
#  '190_1b1_Tc_sc_Meditron',
#  '111_1b3_Tc_sc_Meditron',
#  '151_2p2_Tc_mc_AKGC417L',
#  '170_1b3_Pl_mc_AKGC417L',
#  '158_1p4_Ar_mc_AKGC417L',
#  '191_2b1_Pr_mc_LittC2SE',
#  '138_1p4_Ll_mc_AKGC417L',
#  '125_1b1_Tc_sc_Meditron',
#  '174_1p4_Pl_mc_AKGC417L',
#  '107_3p2_Al_mc_AKGC417L',
#  '160_2b3_Lr_mc_AKGC417L',
#  '147_2b4_Ll_mc_AKGC417L',
#  '186_3b3_Ar_mc_AKGC417L',
#  '139_1b1_Ar_sc_Litt3200',
#  '186_2b3_Pl_mc_AKGC417L',
#  '135_2b1_Pl_mc_LittC2SE',
#  '154_4b4_Al_mc_AKGC417L',
#  '178_2b2_Pr_mc_AKGC417L',
#  '178_1b3_Lr_mc_AKGC417L',
#  '135_2b2_Tc_mc_LittC2SE',
#  '218_1b1_Pl_sc_Meditron',
#  '175_1b1_Pl_sc_Litt3200',
#  '130_3p4_Tc_mc_AKGC417L',
#  '177_1b2_Al_mc_AKGC417L',
#  '133_2p4_Al_mc_AKGC417L',
#  '160_1b2_Al_mc_AKGC417L',
#  '185_1b1_Lr_sc_Litt3200',
#  '147_2b4_Ar_mc_AKGC417L',
#  '154_4b4_Pl_mc_AKGC417L',
#  '218_1b1_Lr_sc_Meditron',
#  '129_1b1_Ar_sc_Meditron',
#  '140_2b2_Tc_mc_LittC2SE',
#  '103_2b2_Ar_mc_LittC2SE',
#  '162_2b3_Pr_mc_AKGC417L',
#  '162_1b2_Ll_mc_AKGC417L',
#  '192_2b2_Al_mc_LittC2SE',
#  '130_2p5_Ar_mc_AKGC417L',
#  '130_3p4_Al_mc_AKGC417L',
#  '130_3b4_Al_mc_AKGC417L',
#  '107_3p2_Ar_mc_AKGC417L',
#  '193_7b3_Lr_mc_AKGC417L',
#  '120_1b1_Al_sc_Meditron',
#  '160_2b4_Ar_mc_AKGC417L',
#  '131_1b1_Al_sc_Meditron',
#  '154_2b4_Lr_mc_AKGC417L',
#  '151_2p4_Pr_mc_AKGC417L',
#  '126_1b1_Al_sc_Meditron',
#  '137_1b1_Ar_sc_Meditron',
#  '170_1b2_Lr_mc_AKGC417L',
#  '130_3p3_Al_mc_AKGC417L',
#  '206_1b1_Pl_sc_Meditron',
#  '186_3b3_Al_mc_AKGC417L',
#  '183_1b1_Pl_sc_Meditron',
#  '130_1p3_Pl_mc_AKGC417L',
#  '203_1p4_Ar_mc_AKGC417L',
#  '145_2b2_Al_mc_AKGC417L',
#  '151_2p2_Lr_mc_AKGC417L',
#  '213_1p2_Al_mc_AKGC417L',
#  '172_2b5_Lr_mc_AKGC417L',
#  '111_1b2_Tc_sc_Meditron',
#  '130_2b3_Ar_mc_AKGC417L',
#  '186_3b3_Pr_mc_AKGC417L',
#  '107_2b5_Ar_mc_AKGC417L',
#  '200_2p3_Lr_mc_AKGC417L',
#  '191_2b2_Tc_mc_LittC2SE',
#  '158_1p2_Tc_mc_AKGC417L',
#  '170_1b2_Tc_mc_AKGC417L',
#  '160_2b4_Pl_mc_AKGC417L',
#  '113_1b1_Lr_sc_Litt3200',
#  '162_2b3_Ar_mc_AKGC417L',
#  '166_1p1_Pr_sc_Meditron',
#  '130_3p3_Pr_mc_AKGC417L',
#  '174_1p2_Lr_mc_AKGC417L',
#  '154_3b3_Ar_mc_AKGC417L',
#  '154_2b4_Ar_mc_AKGC417L',
#  '158_1p4_Al_mc_AKGC417L',
#  '160_1b3_Pr_mc_AKGC417L',
#  '162_2b2_Pl_mc_AKGC417L',
#  '162_1b2_Pl_mc_AKGC417L',
#  '204_7p5_Tc_mc_AKGC417L',
#  '130_3p4_Pl_mc_AKGC417L',
#  '186_2b3_Tc_mc_AKGC417L',
#  '221_2b1_Lr_mc_LittC2SE',
#  '200_2p3_Pr_mc_AKGC417L',
#  '107_2b4_Pl_mc_AKGC417L',
#  '154_2b4_Al_mc_AKGC417L',
#  '221_2b1_Pl_mc_LittC2SE',
#  '176_1b3_Ar_mc_AKGC417L',
#  '151_2p3_Tc_mc_AKGC417L',
#  '130_3p3_Tc_mc_AKGC417L',
#  '201_1b1_Al_sc_Meditron',
#  '166_1p1_Pl_sc_Meditron',
#  '214_1b1_Ar_sc_Meditron',
#  '135_2b2_Pl_mc_LittC2SE',
#  '216_1b1_Al_sc_Meditron',
#  '138_1p3_Lr_mc_AKGC417L',
#  '154_2b4_Ll_mc_AKGC417L',
#  '107_2b3_Ar_mc_AKGC417L',
#  '130_1p2_Pr_mc_AKGC417L',
#  '133_3p4_Tc_mc_AKGC417L',
#  '151_2p3_Ll_mc_AKGC417L',
#  '156_5b3_Ll_mc_AKGC417L',
#  '151_2p2_Ll_mc_AKGC417L',
#  '193_1b2_Tc_mc_AKGC417L',
#  '130_2b3_Al_mc_AKGC417L',
#  '203_1p4_Al_mc_AKGC417L',
#  '134_2b3_Ar_mc_LittC2SE',
#  '198_1b5_Ar_mc_AKGC417L',
#  '130_1p3_Al_mc_AKGC417L',
#  '223_1b1_Al_sc_Meditron',
#  '175_1b1_Pr_sc_Litt3200',
#  '178_1b6_Ll_mc_AKGC417L',
#  '193_7b3_Al_mc_AKGC417L',
#  '144_1b1_Tc_sc_Meditron',
#  '158_1p3_Pr_mc_AKGC417L',
#  '176_2b3_Pr_mc_AKGC417L',
#  '165_1b1_Pr_sc_Meditron',
#  '138_1p4_Ar_mc_AKGC417L',
#  '159_1b1_Ar_sc_Meditron',
#  '109_1b1_Pl_sc_Litt3200',
#  '177_1b2_Pl_mc_AKGC417L',
#  '186_3b3_Lr_mc_AKGC417L',
#  '157_1b1_Lr_sc_Meditron',
#  '166_1p1_Ar_sc_Meditron',
#  '196_1b1_Pr_sc_Meditron',
#  '154_1b3_Pl_mc_AKGC417L',
#  '134_2b2_Ar_mc_LittC2SE',
#  '204_2b5_Al_mc_AKGC417L',
#  '151_2p3_Ar_mc_AKGC417L',
#  '178_1b2_Ar_mc_AKGC417L',
#  '193_1b2_Pl_mc_AKGC417L',
#  '120_1b1_Ar_sc_Meditron',
#  '133_2p3_Ar_mc_AKGC417L',
#  '205_3b4_Ar_mc_AKGC417L',
#  '176_1b4_Pl_mc_AKGC417L',
#  '135_2b2_Ar_mc_LittC2SE',
#  '116_1b2_Pl_sc_Meditron',
#  '113_1b1_Al_sc_Litt3200',
#  '226_1b1_Ll_sc_Meditron',
#  '207_2b2_Al_mc_AKGC417L',
#  '133_2p2_Al_mc_AKGC417L',
#  '114_1b4_Ar_mc_AKGC417L',
#  '107_2b5_Lr_mc_AKGC417L',
#  '122_2b1_Tc_mc_LittC2SE',
#  '188_1b1_Tc_sc_Meditron',
#  '105_1b1_Tc_sc_Meditron',
#  '221_2b2_Ar_mc_LittC2SE',
#  '151_3p2_Pr_mc_AKGC417L',
#  '130_1p3_Ll_mc_AKGC417L',
#  '158_1b3_Ar_mc_LittC2SE',
#  '122_2b2_Al_mc_LittC2SE',
#  '177_2b4_Pr_mc_AKGC417L',
#  '200_2p2_Tc_mc_AKGC417L',
#  '113_1b1_Ar_sc_Litt3200',
#  '207_2b4_Pl_mc_AKGC417L',
#  '186_2b2_Pr_mc_AKGC417L',
#  '146_8p3_Al_mc_AKGC417L',
#  '140_2b3_Tc_mc_LittC2SE',
#  '205_2b3_Al_mc_AKGC417L',
#  '133_3p2_Ar_mc_AKGC417L',
#  '180_1b4_Pl_mc_AKGC417L',
#  '176_1b4_Ar_mc_AKGC417L',
#  '147_1b4_Tc_mc_AKGC417L',
#  '145_2b2_Ar_mc_AKGC417L',
#  '193_7b3_Pl_mc_AKGC417L',
#  '172_2b5_Pl_mc_AKGC417L',
#  '138_2p2_Pr_mc_AKGC417L',
#  '174_1p4_Ll_mc_AKGC417L',
#  '204_7p5_Al_mc_AKGC417L',
#  '205_4b2_Ar_mc_AKGC417L',
#  '207_2b3_Tc_mc_AKGC417L',
#  '203_1p4_Tc_mc_AKGC417L',
#  '172_1b3_Pr_mc_AKGC417L',
#  '180_1b4_Lr_mc_AKGC417L',
#  '138_1p3_Ll_mc_AKGC417L',
#  '221_2b2_Al_mc_LittC2SE',
#  '170_1b3_Lr_mc_AKGC417L',
#  '170_1b2_Ar_mc_AKGC417L',
#  '162_1b2_Ar_mc_AKGC417L',
#  '176_1b3_Al_mc_AKGC417L',
#  '147_1b3_Tc_mc_AKGC417L',
#  '174_1p3_Pl_mc_AKGC417L',
#  '218_1b1_Pr_sc_Meditron',
#  '156_5b3_Ar_mc_AKGC417L',
#  '174_1p3_Pr_mc_AKGC417L',
#  '223_1b1_Ar_sc_Meditron',
#  '130_2b2_Al_mc_AKGC417L',
#  '156_2b3_Ar_mc_AKGC417L',
#  '154_3b3_Al_mc_AKGC417L',
#  '141_1b3_Pr_mc_LittC2SE',
#  '154_1b3_Ll_mc_AKGC417L',
#  '207_2b2_Pr_mc_AKGC417L',
#  '207_3b2_Tc_mc_AKGC417L',
#  '138_2p2_Ar_mc_AKGC417L',
#  '130_1p4_Al_mc_AKGC417L',
#  '133_2p4_Pl_mc_AKGC417L',
#  '120_1b1_Pl_sc_Meditron',
#  '108_1b1_Al_sc_Meditron',
#  '192_2b3_Ar_mc_LittC2SE',
#  '177_1b4_Al_mc_AKGC417L',
#  '172_1b4_Al_mc_AKGC417L',
#  '109_1b1_Al_sc_Litt3200',
#  '200_3p4_Al_mc_AKGC417L',
#  '219_2b1_Tc_mc_LittC2SE',
#  '120_1b1_Pr_sc_Meditron',
#  '213_1p3_Ar_mc_AKGC417L',
#  '162_2b4_Al_mc_AKGC417L',
#  '200_2p2_Pr_mc_AKGC417L',
#  '207_2b3_Ar_mc_AKGC417L',
#  '107_2b5_Tc_mc_AKGC417L',
#  '213_1p3_Pr_mc_AKGC417L',
#  '223_1b1_Lr_sc_Meditron',
#  '104_1b1_Ll_sc_Litt3200',
#  '107_3p2_Lr_mc_AKGC417L',
#  '117_1b2_Tc_mc_LittC2SE',
#  '171_1b1_Al_sc_Meditron',
#  '156_8b3_Ar_mc_AKGC417L',
#  '207_3b2_Pr_mc_AKGC417L',
#  '205_3b4_Al_mc_AKGC417L',
#  '182_1b1_Tc_sc_Meditron',
#  '151_2p3_Pr_mc_AKGC417L',
#  '139_1b1_Lr_sc_Litt3200',
#  '151_2p2_Pr_mc_AKGC417L',
#  '130_3p2_Pl_mc_AKGC417L',
#  '188_1b1_Pl_sc_Meditron',
#  '104_1b1_Pr_sc_Litt3200',
#  '201_1b1_Ar_sc_Meditron',
#  '205_1b3_Ar_mc_AKGC417L',
#  '186_2b4_Pl_mc_AKGC417L',
#  '205_2b3_Ar_mc_AKGC417L',
#  '147_2b2_Ar_mc_AKGC417L',
#  '211_2p3_Tc_mc_AKGC417L',
#  '183_1b1_Tc_sc_Meditron',
#  '207_2b3_Pl_mc_AKGC417L',
#  '156_5b3_Pr_mc_AKGC417L',
#  '130_1p3_Tc_mc_AKGC417L',
#  '151_3p2_Tc_mc_AKGC417L',
#  '150_1b2_Al_sc_Meditron',
#  '193_7b3_Ll_mc_AKGC417L',
#  '162_1b2_Pr_mc_AKGC417L',
#  '107_2b3_Ll_mc_AKGC417L',
#  '146_2b4_Lr_mc_AKGC417L',
#  '133_2p3_Pr_mc_AKGC417L',
#  '106_2b1_Pl_mc_LittC2SE',
#  '198_6p1_Ll_mc_AKGC417L',
#  '130_2b2_Lr_mc_AKGC417L',
#  '174_1p2_Tc_mc_AKGC417L',
#  '218_1b1_Ar_sc_Meditron',
#  '158_1p4_Pl_mc_AKGC417L',
#  '198_6p1_Pl_mc_AKGC417L',
#  '135_2b3_Tc_mc_LittC2SE',
#  '112_1p1_Pr_sc_Litt3200',
#  '162_2b3_Tc_mc_AKGC417L',
#  '151_2p3_Lr_mc_AKGC417L',
#  '170_1b3_Pr_mc_AKGC417L',
#  '151_2p4_Tc_mc_AKGC417L',
#  '158_1p2_Lr_mc_AKGC417L',
#  '193_7b3_Ar_mc_AKGC417L',
#  '157_1b1_Pr_sc_Meditron',
#  '225_1b1_Pl_sc_Meditron',
#  '104_1b1_Lr_sc_Litt3200',
#  '138_1p3_Al_mc_AKGC417L',
#  '134_2b1_Al_mc_LittC2SE',
#  '163_2b2_Ar_mc_AKGC417L',
#  '212_2b2_Tc_mc_LittC2SE',
#  '213_2p2_Al_mc_AKGC417L',
#  '203_1p2_Pl_mc_AKGC417L',
#  '174_1p2_Pr_mc_AKGC417L',
#  '159_1b1_Al_sc_Meditron',
#  '107_2b5_Pr_mc_AKGC417L',
#  '112_1b1_Lr_sc_Meditron',
#  '203_2p3_Tc_mc_AKGC417L',
#  '199_2b3_Ll_mc_LittC2SE',
#  '112_1p1_Pl_sc_Litt3200',
#  '162_2b4_Pr_mc_AKGC417L',
#  '174_1p3_Ll_mc_AKGC417L',
#  '156_2b3_Pl_mc_AKGC417L',
#  '176_2b3_Tc_mc_AKGC417L',
#  '176_2b3_Ll_mc_AKGC417L',
#  '221_2b2_Pl_mc_LittC2SE',
#  '151_2p3_Pl_mc_AKGC417L',
#  '160_1b4_Ar_mc_AKGC417L',
#  '177_2b4_Lr_mc_AKGC417L',
#  '154_2b4_Pr_mc_AKGC417L',
#  '213_1p2_Pr_mc_AKGC417L',
#  '172_1b4_Pl_mc_AKGC417L',
#  '203_1p2_Lr_mc_AKGC417L',
#  '213_2p2_Tc_mc_AKGC417L',
#  '138_1p2_Tc_mc_AKGC417L',
#  '130_2b2_Ar_mc_AKGC417L',
#  '138_2p2_Tc_mc_AKGC417L',
#  '142_1b1_Pl_mc_LittC2SE',
#  '147_2b4_Lr_mc_AKGC417L',
#  '205_1b3_Pr_mc_AKGC417L',
#  '110_1p1_Lr_sc_Meditron',
#  '178_1b6_Ar_mc_AKGC417L',
#  '215_1b2_Ar_sc_Meditron',
#  '219_2b2_Tc_mc_LittC2SE',
#  '207_3b2_Lr_mc_AKGC417L',
#  '158_1p3_Al_mc_AKGC417L',
#  '124_1b1_Al_sc_Litt3200',
#  '193_1b4_Lr_mc_AKGC417L',
#  '207_3b2_Al_mc_AKGC417L',
#  '135_2b3_Ar_mc_LittC2SE',
#  '181_1b3_Tc_mc_LittC2SE',
#  '154_1b3_Pr_mc_AKGC417L',
#  '160_1b2_Tc_mc_AKGC417L',
#  '138_1p3_Pr_mc_AKGC417L',
#  '121_1b1_Tc_sc_Meditron',
#  '186_3b3_Pl_mc_AKGC417L',
#  '130_2b3_Pr_mc_AKGC417L',
#  '149_1b1_Pl_sc_Meditron',
#  '198_6p1_Lr_mc_AKGC417L',
#  '162_1b2_Al_mc_AKGC417L',
#  '213_1p2_Tc_mc_AKGC417L',
#  '172_1b5_Lr_mc_AKGC417L',
#  '138_1p4_Lr_mc_AKGC417L',
#  '133_2p3_Pl_mc_AKGC417L',
#  '133_3p2_Pr_mc_AKGC417L',
#  '213_2p2_Pr_mc_AKGC417L',
#  '201_1b3_Ar_sc_Meditron',
#  '130_2b4_Pl_mc_AKGC417L',
#  '200_3p4_Pr_mc_AKGC417L',
#  '186_2b4_Ar_mc_AKGC417L',
#  '163_2b2_Ll_mc_AKGC417L',
#  '138_1p2_Ll_mc_AKGC417L',
#  '174_1p4_Ar_mc_AKGC417L',
#  '145_2b2_Pr_mc_AKGC417L',
#  '107_3p2_Tc_mc_AKGC417L',
#  '221_2b3_Al_mc_LittC2SE',
#  '172_1b5_Pr_mc_AKGC417L',
#  '170_1b4_Lr_mc_AKGC417L',
#  '178_2b2_Lr_mc_AKGC417L',
#  '160_1b2_Pl_mc_AKGC417L',
#  '213_1p3_Pl_mc_AKGC417L',
#  '205_4b2_Pr_mc_AKGC417L',
#  '170_1b3_Ll_mc_AKGC417L',
#  '124_1b1_Pl_sc_Litt3200',
#  '200_2p3_Tc_mc_AKGC417L',
#  '186_2b4_Al_mc_AKGC417L',
#  '174_1p3_Tc_mc_AKGC417L',
#  '116_1b2_Tc_sc_Meditron',
#  '170_1b4_Tc_mc_AKGC417L',
#  '172_1b3_Pl_mc_AKGC417L',
#  '130_1p3_Lr_mc_AKGC417L',
#  '203_1p4_Pl_mc_AKGC417L',
#  '192_2b2_Ar_mc_LittC2SE',
#  '134_2b1_Ar_mc_LittC2SE',
#  '186_2b2_Pl_mc_AKGC417L',
#  '158_2p2_Ar_mc_AKGC417L',
#  '193_1b2_Pr_mc_AKGC417L',
#  '176_2b3_Ar_mc_AKGC417L',
#  '130_3b4_Pl_mc_AKGC417L',
#  '160_1b3_Ar_mc_AKGC417L',
#  '146_2b4_Pr_mc_AKGC417L',
#  '174_1p4_Tc_mc_AKGC417L',
#  '211_1p2_Pr_mc_AKGC417L',
#  '130_2b4_Ar_mc_AKGC417L',
#  '176_1b3_Pr_mc_AKGC417L',
#  '114_1b4_Lr_mc_AKGC417L',
#  '107_3p2_Ll_mc_AKGC417L',
#  '149_1b1_Lr_sc_Meditron',
#  '172_1b4_Lr_mc_AKGC417L',
#  '174_1p3_Lr_mc_AKGC417L',
#  '151_2p3_Al_mc_AKGC417L',
#  '154_1b3_Lr_mc_AKGC417L',
#  '162_2b3_Lr_mc_AKGC417L',
#  '147_2b2_Al_mc_AKGC417L',
#  '162_2b4_Tc_mc_AKGC417L',
#  '172_1b5_Ar_mc_AKGC417L',
#  '174_1p2_Pl_mc_AKGC417L',
#  '198_1b5_Pr_mc_AKGC417L',
#  '151_3p2_Al_mc_AKGC417L',
#  '154_1b3_Tc_mc_AKGC417L',
#  '207_2b3_Al_mc_AKGC417L',
#  '130_2p5_Lr_mc_AKGC417L',
#  '226_1b1_Pl_sc_LittC2SE',
#  '178_1b6_Pr_mc_AKGC417L',
#  '138_1p3_Tc_mc_AKGC417L',
#  '158_1p3_Lr_mc_AKGC417L',
#  '203_1p3_Pr_mc_AKGC417L',
#  '195_1b1_Pr_sc_Litt3200',
#  '213_2p2_Ar_mc_AKGC417L',
#  '156_2b3_Lr_mc_AKGC417L',
#  '213_1p2_Pl_mc_AKGC417L',
#  '141_1b3_Ar_mc_LittC2SE',
#  '177_1b4_Pl_mc_AKGC417L',
#  '153_1b1_Al_sc_Meditron',
#  '223_1b1_Pr_sc_Meditron',
#  '218_1b1_Al_sc_Meditron',
#  '176_1b3_Pl_mc_AKGC417L',
#  '174_2p3_Al_mc_AKGC417L',
#  '221_2b3_Lr_mc_LittC2SE',
#  '130_1p2_Al_mc_AKGC417L',
#  '128_1b3_Tc_mc_LittC2SE',
#  '165_1b1_Ar_sc_Meditron',
#  '135_2b3_Al_mc_LittC2SE',
#  '120_1b1_Lr_sc_Meditron',
#  '208_1b1_Ll_sc_Meditron',
#  '145_3b2_Ar_mc_AKGC417L',
#  '140_2b3_Ll_mc_LittC2SE',
#  '213_1p2_Lr_mc_AKGC417L',
#  '178_1b3_Ar_mc_AKGC417L',
#  '211_1p2_Ar_mc_AKGC417L',
#  '176_1b3_Lr_mc_AKGC417L',
#  '193_1b2_Al_mc_AKGC417L',
#  '109_1b1_Pr_sc_Litt3200',
#  '218_1p1_Ar_sc_Litt3200',
#  '177_1b2_Pr_mc_AKGC417L',
#  '203_1p2_Pr_mc_AKGC417L',
#  '107_2b4_Ll_mc_AKGC417L',
#  '151_2p4_Al_mc_AKGC417L',
#  '104_1b1_Ar_sc_Litt3200',
#  '178_2b2_Al_mc_AKGC417L',
#  '185_1b1_Ar_sc_Litt3200',
#  '135_2b1_Ar_mc_LittC2SE',
#  '215_1b3_Tc_sc_Meditron',
#  '167_1b1_Pr_sc_Meditron',
#  '203_1p2_Tc_mc_AKGC417L',
#  '192_2b1_Al_mc_LittC2SE',
#  '124_1b1_Ll_sc_Litt3200',
#  '118_1b1_Ar_sc_Litt3200',
#  '213_1p5_Al_mc_AKGC417L',
#  '205_4b2_Lr_mc_AKGC417L',
#  '193_7b3_Tc_mc_AKGC417L',
#  '155_2b1_Al_mc_LittC2SE',
#  '138_1p3_Ar_mc_AKGC417L',
#  '132_2b1_Lr_mc_LittC2SE',
#  '162_2b2_Ar_mc_AKGC417L',
#  '118_1b1_Pl_sc_Litt3200',
#  '138_1p2_Pl_mc_AKGC417L',
#  '133_2p4_Tc_mc_AKGC417L',
#  '202_1b1_Ar_sc_Meditron',
#  '217_1b1_Tc_sc_Meditron',
#  '160_1b4_Lr_mc_AKGC417L',
#  '115_1b1_Ar_sc_Meditron',
#  '174_2p3_Ar_mc_AKGC417L',
#  '207_2b4_Pr_mc_AKGC417L',
#  '175_1b1_Ar_sc_Litt3200',
#  '156_8b3_Lr_mc_AKGC417L',
#  '160_1b2_Ar_mc_AKGC417L',
#  '207_2b2_Tc_mc_AKGC417L',
#  '200_2p4_Ar_mc_AKGC417L',
#  '122_2b2_Ar_mc_LittC2SE',
#  '147_2b3_Lr_mc_AKGC417L',
#  '201_1b2_Al_sc_Meditron',
#  '186_3b3_Tc_mc_AKGC417L',
#  '130_3p2_Pr_mc_AKGC417L',
#  '130_1p2_Lr_mc_AKGC417L',
#  '154_2b4_Tc_mc_AKGC417L',
#  '178_1b2_Tc_mc_AKGC417L',
#  '200_3p4_Tc_mc_AKGC417L',
#  '223_1b1_Pl_sc_Meditron',
#  '176_1b4_Ll_mc_AKGC417L',
#  '203_2p3_Ar_mc_AKGC417L',
#  '206_1b1_Ar_sc_Meditron',
#  '207_2b4_Tc_mc_AKGC417L',
#  '195_1b1_Ll_sc_Litt3200',
#  '158_1p3_Tc_mc_AKGC417L',
#  '186_2b3_Lr_mc_AKGC417L',
#  '160_1b4_Pl_mc_AKGC417L',
#  '194_1b1_Pr_sc_Meditron',
#  '200_2p4_Pl_mc_AKGC417L',
#  '201_1b2_Ar_sc_Meditron',
#  '130_3p2_Ar_mc_AKGC417L',
#  '224_1b1_Tc_sc_Meditron',
#  '200_2p3_Al_mc_AKGC417L',
#  '138_1p4_Tc_mc_AKGC417L',
#  '159_1b1_Ll_sc_Meditron',
#  '160_1b4_Pr_mc_AKGC417L',
#  '216_1b1_Pl_sc_Meditron',
#  '109_1b1_Ll_sc_Litt3200',
#  '146_2b4_Ar_mc_AKGC417L',
#  '170_2b2_Lr_mc_AKGC417L',
#  '160_1b4_Tc_mc_AKGC417L',
#  '122_2b3_Tc_mc_LittC2SE',
#  '130_3p2_Tc_mc_AKGC417L',
#  '186_2b2_Al_mc_AKGC417L',
#  '198_1b5_Al_mc_AKGC417L',
#  '130_2b4_Lr_mc_AKGC417L',
#  '172_1b5_Pl_mc_AKGC417L',
#  '147_2b4_Pl_mc_AKGC417L',
#  '198_1b5_Ll_mc_AKGC417L',
#  '133_2p3_Al_mc_AKGC417L',
#  '178_2b2_Tc_mc_AKGC417L',
#  '151_3p2_Ar_mc_AKGC417L',
#  '198_6p1_Tc_mc_AKGC417L',
#  '195_1b1_Lr_sc_Litt3200',
#  '101_1b1_Al_sc_Meditron',
#  '204_7p5_Pr_mc_AKGC417L',
#  '146_8p3_Ar_mc_AKGC417L',
#  '203_2p3_Al_mc_AKGC417L',
#  '174_2p3_Pr_mc_AKGC417L',
#  '158_1p2_Pl_mc_AKGC417L',
#  '133_2p2_Tc_mc_AKGC417L',
#  '178_1b6_Al_mc_AKGC417L',
#  '172_1b3_Al_mc_AKGC417L',
#  '160_2b4_Tc_mc_AKGC417L',
#  '176_2b3_Lr_mc_AKGC417L',
#  '101_1b1_Pr_sc_Meditron',
#  '151_2p2_Ar_mc_AKGC417L',
#  '172_2b5_Ar_mc_AKGC417L',
#  '133_3p2_Pl_mc_AKGC417L',
#  '130_2b3_Pl_mc_AKGC417L',
#  '160_1b2_Lr_mc_AKGC417L',
#  '162_2b2_Al_mc_AKGC417L',
#  '130_2p5_Al_mc_AKGC417L',
#  '176_2b3_Pl_mc_AKGC417L',
#  '203_1p3_Al_mc_AKGC417L',
#  '203_2p3_Pr_mc_AKGC417L',
#  '172_2b5_Al_mc_AKGC417L',
#  '135_2b3_Pr_mc_LittC2SE',
#  '135_2b3_Pl_mc_LittC2SE',
#  '222_1b1_Ar_sc_Meditron',
#  '204_7p5_Lr_mc_AKGC417L',
#  '195_1b1_Al_sc_Litt3200',
#  '141_1b2_Lr_mc_LittC2SE',
#  '107_3p2_Pr_mc_AKGC417L',
#  '138_1p2_Pr_mc_AKGC417L',
#  '207_2b2_Ar_mc_AKGC417L',
#  '174_2p3_Pl_mc_AKGC417L',
#  '107_2b3_Tc_mc_AKGC417L',
#  '172_1b5_Ll_mc_AKGC417L',
#  '107_2b5_Ll_mc_AKGC417L',
#  '156_8b3_Al_mc_AKGC417L',
#  '130_2b2_Pr_mc_AKGC417L',
#  '179_1b1_Tc_sc_Meditron',
#  '130_3b4_Pr_mc_AKGC417L',
#  '107_2b4_Pr_mc_AKGC417L',
#  '213_1p2_Ar_mc_AKGC417L',
#  '154_2b4_Pl_mc_AKGC417L',
#  '130_1p2_Ll_mc_AKGC417L',
#  '200_2p4_Pr_mc_AKGC417L',
#  '176_2b3_Al_mc_AKGC417L',
#  '176_1b4_Al_mc_AKGC417L',
#  '178_2b2_Ar_mc_AKGC417L',
#  '106_2b1_Pr_mc_LittC2SE',
#  '185_1b1_Ll_sc_Litt3200',
#  '130_2b2_Pl_mc_AKGC417L',
#  '135_2b2_Al_mc_LittC2SE',
#  '151_3p3_Ll_mc_AKGC417L',
#  '163_2b2_Pr_mc_AKGC417L',
#  '170_2b2_Pr_mc_AKGC417L',
#  '151_2p2_Al_mc_AKGC417L',
#  '172_1b3_Ar_mc_AKGC417L',
#  '174_1p2_Ar_mc_AKGC417L',
#  '177_2b4_Tc_mc_AKGC417L',
#  '224_1b2_Al_sc_Meditron',
#  '191_2b1_Pl_mc_LittC2SE',
#  '154_4b4_Ar_mc_AKGC417L',
#  '110_1p1_Ll_sc_Meditron',
#  '205_3b4_Pr_mc_AKGC417L',
#  '138_1p4_Pl_mc_AKGC417L',
#  '107_3p2_Pl_mc_AKGC417L',
#  '174_1p3_Ar_mc_AKGC417L',
#  '135_2b1_Al_mc_LittC2SE',
#  '205_2b2_Pr_mc_AKGC417L',
#  '141_1b3_Al_mc_LittC2SE',
#  '112_1p1_Ll_sc_Litt3200',
#  '193_1b2_Ar_mc_AKGC417L',
#  '137_1b1_Ll_sc_Meditron',
#  '138_1p2_Lr_mc_AKGC417L',
#  '213_1p5_Ar_mc_AKGC417L',
#  '180_1b4_Al_mc_AKGC417L',
#  '141_1b2_Pr_mc_LittC2SE',
#  '205_1b3_Al_mc_AKGC417L',
#  '146_2b4_Al_mc_AKGC417L',
#  '205_4b2_Al_mc_AKGC417L',
#  '200_3p4_Pl_mc_AKGC417L',
#  '186_2b2_Lr_mc_AKGC417L',
#  '218_1p1_Pl_sc_Litt3200',
#  '177_2b4_Al_mc_AKGC417L',
#  '145_2b2_Lr_mc_AKGC417L',
#  '162_2b2_Tc_mc_AKGC417L',
#  '154_4b4_Pr_mc_AKGC417L',
#  '170_1b4_Pl_mc_AKGC417L',
#  '170_1b2_Pr_mc_AKGC417L',
#  '205_1b3_Pl_mc_AKGC417L',
#  '200_2p2_Al_mc_AKGC417L',
#  '172_1b4_Pr_mc_AKGC417L',
#  '198_6p1_Ar_mc_AKGC417L',
#  '130_2p5_Pr_mc_AKGC417L',
#  '211_2p2_Tc_mc_AKGC417L',
#  '151_2p4_Ar_mc_AKGC417L',
#  '205_1b3_Lr_mc_AKGC417L',
#  '139_1b1_Pl_sc_Litt3200',
#  '112_1b1_Ar_sc_Meditron',
#  '130_1p4_Ar_mc_AKGC417L',
#  '160_1b4_Al_mc_AKGC417L',
#  '139_1b1_Ll_sc_Litt3200',
#  '107_2b3_Al_mc_AKGC417L',
#  '174_2p3_Tc_mc_AKGC417L',
#  '203_2p3_Pl_mc_AKGC417L',
#  '146_8p3_Pr_mc_AKGC417L',
#  '170_2b2_Ar_mc_AKGC417L',
#  '177_1b4_Ar_mc_AKGC417L',
#  '158_1p2_Ll_mc_AKGC417L',
#  '172_1b3_Tc_mc_AKGC417L',
#  '213_1p5_Pl_mc_AKGC417L',
#  '162_2b3_Pl_mc_AKGC417L',
#  '114_1b4_Pr_mc_AKGC417L',
#  '185_1b1_Al_sc_Litt3200',
#  '154_4b4_Ll_mc_AKGC417L',
#  '172_1b4_Ar_mc_AKGC417L',
#  '201_1b3_Al_sc_Meditron',
#  '130_3p2_Al_mc_AKGC417L',
#  '107_2b3_Pr_mc_AKGC417L',
#  '220_1b1_Tc_mc_LittC2SE',
#  '162_2b4_Pl_mc_AKGC417L',
#  '107_2b4_Lr_mc_AKGC417L',
#  '156_5b3_Pl_mc_AKGC417L',
#  '207_3b2_Ar_mc_AKGC417L',
#  '140_2b2_Ll_mc_LittC2SE',
#  '139_1b1_Pr_sc_Litt3200',
#  '178_1b3_Pl_mc_AKGC417L',
#  '158_1p3_Ll_mc_AKGC417L',
#  '174_1p4_Pr_mc_AKGC417L',
#  '177_1b4_Pr_mc_AKGC417L',
#  '146_2b4_Ll_mc_AKGC417L',
#  '130_1p2_Tc_mc_AKGC417L',
#  '139_1b1_Al_sc_Litt3200',
#  '130_2b3_Lr_mc_AKGC417L',
#  '138_1p3_Pl_mc_AKGC417L',
#  '172_1b4_Tc_mc_AKGC417L',
#  '124_1b1_Pr_sc_Litt3200',
#  '133_2p2_Pl_mc_AKGC417L',
#  '178_1b2_Lr_mc_AKGC417L',
#  '162_2b3_Al_mc_AKGC417L',
#  '118_1b1_Al_sc_Litt3200',
#  '130_2b3_Tc_mc_AKGC417L',
#  '222_1b1_Lr_sc_Meditron',
#  '198_1b5_Tc_mc_AKGC417L',
#  '114_1b4_Pl_mc_AKGC417L',
#  '141_1b1_Pr_mc_LittC2SE',
#  '213_1p5_Tc_mc_AKGC417L',
#  '176_1b4_Pr_mc_AKGC417L',
#  '130_2p3_Pl_mc_AKGC417L',
#  '109_1b1_Ar_sc_Litt3200',
#  '151_2p4_Ll_mc_AKGC417L',
#  '200_2p4_Tc_mc_AKGC417L',
#  '154_4b4_Lr_mc_AKGC417L',
#  '149_1b1_Al_sc_Meditron',
#  '160_1b3_Pl_mc_AKGC417L',
#  '207_2b2_Pl_mc_AKGC417L',
#  '152_1b1_Al_sc_Meditron',
#  '218_1p1_Pr_sc_Litt3200',
#  '121_1p1_Tc_sc_Meditron',
#  '141_1b2_Tc_mc_LittC2SE',
#  '156_8b3_Pl_mc_AKGC417L',
#  '147_2b3_Pl_mc_AKGC417L',
#  '178_1b6_Tc_mc_AKGC417L',
#  '176_1b4_Lr_mc_AKGC417L',
#  '122_2b2_Tc_mc_LittC2SE',
#  '211_1p3_Ar_mc_AKGC417L',
#  '117_1b3_Tc_mc_LittC2SE',
#  '135_2b1_Tc_mc_LittC2SE',
#  '177_1b2_Ar_mc_AKGC417L',
#  '138_1p4_Pr_mc_AKGC417L',
#  '130_2b4_Al_mc_AKGC417L',
#  '170_1b4_Al_mc_AKGC417L',
#  '160_2b4_Pr_mc_AKGC417L',
#  '130_3b4_Ar_mc_AKGC417L',
#  '186_2b3_Ar_mc_AKGC417L',
#  '188_1b1_Ar_sc_Meditron',
#  '211_1p5_Ar_mc_AKGC417L',
#  '175_1b1_Al_sc_Litt3200',
#  '221_2b1_Ar_mc_LittC2SE',
#  '146_8p3_Pl_mc_AKGC417L',
#  '186_2b2_Ar_mc_AKGC417L',
#  '177_1b4_Lr_mc_AKGC417L',
#  '158_1p4_Pr_mc_AKGC417L',
#  '141_1b2_Ar_mc_LittC2SE',
#  '107_2b3_Pl_mc_AKGC417L',
#  '206_1b1_Lr_sc_Meditron',
#  '168_1b1_Al_sc_Meditron',
#  '113_1b1_Pr_sc_Litt3200',
#  '158_1p2_Ar_mc_AKGC417L',
#  '148_1b1_Al_sc_Meditron',
#  '130_3b3_Ll_mc_AKGC417L',
#  '213_2p2_Pl_mc_AKGC417L',
#  '114_1b4_Al_mc_AKGC417L',
#  '189_1b2_Lr_mc_LittC2SE',
#  '203_1p2_Al_mc_AKGC417L',
#  '200_2p4_Al_mc_AKGC417L',
#  '147_2b4_Al_mc_AKGC417L',
#  '186_2b4_Lr_mc_AKGC417L',
#  '147_2b2_Pl_mc_AKGC417L',
#  '102_1b1_Ar_sc_Meditron',
#  '170_1b2_Pl_mc_AKGC417L',
#  '204_7p5_Ll_mc_AKGC417L',
#  '158_1p2_Al_mc_AKGC417L',
#  '130_1p4_Pl_mc_AKGC417L',
#  '147_2b3_Ar_mc_AKGC417L',
#  '118_1b1_Pr_sc_Litt3200',
#  '147_2b3_Ll_mc_AKGC417L',
#  '170_1b4_Ar_mc_AKGC417L',
#  '176_1b4_Tc_mc_AKGC417L',
#  '138_1p2_Al_mc_AKGC417L',
#  '167_1b1_Al_sc_Meditron',
#  '181_1b1_Tc_mc_LittC2SE',
#  '163_2b2_Lr_mc_AKGC417L',
#  '181_1b1_Ar_mc_LittC2SE',
#  '130_3p4_Pr_mc_AKGC417L',
#  '122_2b1_Al_mc_LittC2SE',
#  '163_2b2_Al_mc_AKGC417L',
#  '185_1b1_Pl_sc_Litt3200',
#  '173_1b1_Al_sc_Meditron',
#  '130_2b2_Tc_mc_AKGC417L',
#  '198_1b5_Lr_mc_AKGC417L',
#  '178_1b2_Al_mc_AKGC417L',
#  '109_1b1_Lr_sc_Litt3200',
#  '198_6p1_Al_mc_AKGC417L',
#  '170_1b2_Al_mc_AKGC417L',
#  '154_3b3_Ll_mc_AKGC417L',
#  '157_1b1_Pl_sc_Meditron',
#  '123_1b1_Al_sc_Meditron',
#  '204_2b5_Ll_mc_AKGC417L',
#  '175_1b1_Ll_sc_Litt3200',
#  '177_2b4_Pl_mc_AKGC417L',
#  '147_2b3_Al_mc_AKGC417L',
#  '145_3b2_Lr_mc_AKGC417L',
#  '138_2p2_Al_mc_AKGC417L',
#  '165_1b1_Pl_sc_Meditron',
#  '176_1b3_Ll_mc_AKGC417L',
#  '188_1b1_Al_sc_Meditron',
#  '207_2b4_Al_mc_AKGC417L',
#  '175_1b1_Lr_sc_Litt3200',
#  '184_1b1_Ar_sc_Meditron',
#  '219_2b1_Ar_mc_LittC2SE',
#  '200_2p3_Ar_mc_AKGC417L',
#  '178_1b2_Pl_mc_AKGC417L',
#  '169_1b2_Ll_sc_Meditron',
#  '104_1b1_Al_sc_Litt3200',
#  '118_1b1_Lr_sc_Litt3200',
#  '221_2b3_Ar_mc_LittC2SE',
#  '213_1p3_Al_mc_AKGC417L',
#  '130_2p5_Pl_mc_AKGC417L',
#  '162_2b2_Pr_mc_AKGC417L',
#  '158_1p2_Pr_mc_AKGC417L',
#  '133_2p2_Ar_mc_AKGC417L',
#  '203_1p2_Ar_mc_AKGC417L',
#  '177_1b4_Tc_mc_AKGC417L',
#  '151_2p4_Pl_mc_AKGC417L',
#  '134_2b2_Al_mc_LittC2SE',
#  '104_1b1_Pl_sc_Litt3200',
#  '219_2b2_Ar_mc_LittC2SE',
#  '166_1p1_Ll_sc_Meditron',
#  '138_2p2_Ll_mc_AKGC417L',
#  '163_8b3_Al_mc_AKGC417L',
#  '158_1p3_Ar_mc_AKGC417L',
#  '154_1b3_Ar_mc_AKGC417L',
#  '205_2b4_Pl_mc_AKGC417L',
#  '172_2b5_Tc_mc_AKGC417L',
#  '122_2b1_Ar_mc_LittC2SE',
#  '178_1b6_Lr_mc_AKGC417L',
#  '197_1b1_Al_sc_Meditron',
#  '130_1p4_Ll_mc_AKGC417L',
#  '107_2b4_Tc_mc_AKGC417L',
#  '172_1b3_Lr_mc_AKGC417L',
#  '169_1b1_Lr_sc_Meditron',
#  '207_3b2_Pl_mc_AKGC417L',
#  '219_2b3_Tc_mc_LittC2SE',
#  '210_1b1_Al_sc_Meditron',
#  '162_1b2_Tc_mc_AKGC417L',
#  '133_3p2_Al_mc_AKGC417L',
#  '133_2p3_Tc_mc_AKGC417L',
#  '163_8b3_Lr_mc_AKGC417L',
#  '157_1b1_Ar_sc_Meditron',
#  '178_1b6_Pl_mc_AKGC417L',
#  '170_1b3_Tc_mc_AKGC417L',
#  '130_1p3_Ar_mc_AKGC417L',
#  '203_1p3_Pl_mc_AKGC417L',
#  '186_2b3_Pr_mc_AKGC417L',
#  '151_3p2_Pl_mc_AKGC417L',
#  '200_2p3_Pl_mc_AKGC417L',
#  '136_1b1_Ar_sc_Meditron',
#  '200_2p2_Ar_mc_AKGC417L',
#  '213_1p5_Pr_mc_AKGC417L',
#  '180_1b4_Pr_mc_AKGC417L',
#  '203_1p3_Tc_mc_AKGC417L',
#  '161_1b1_Pl_sc_Meditron',
#  '211_2p4_Tc_mc_AKGC417L',
#  '107_2b3_Lr_mc_AKGC417L',
#  '138_1p2_Ar_mc_AKGC417L',
#  '156_5b3_Al_mc_AKGC417L',
#  '163_8b3_Ar_mc_AKGC417L',
#  '151_2p2_Pl_mc_AKGC417L',
#  '107_2b4_Al_mc_AKGC417L',
#  '177_1b2_Lr_mc_AKGC417L',
#  '200_2p2_Pl_mc_AKGC417L',
#  '130_3p3_Pl_mc_AKGC417L',
#  '207_2b4_Ar_mc_AKGC417L',
#  '223_1b1_Ll_sc_Meditron',
#  '195_1b1_Pl_sc_Litt3200',
#  '194_1b1_Lr_sc_Meditron',
#  '221_2b1_Al_mc_LittC2SE',
#  '163_2b2_Tc_mc_AKGC417L',
#  '192_2b1_Ar_mc_LittC2SE',
#  '187_1b1_Ll_sc_Meditron',
#  '203_1p3_Ar_mc_AKGC417L',
#  '226_1b1_Al_sc_Meditron',
#  '107_2b4_Ar_mc_AKGC417L',
#  '133_2p4_Pr_mc_AKGC417L',
#  '130_1p2_Pl_mc_AKGC417L',
#  '203_1p4_Pr_mc_AKGC417L',
#  '185_1b1_Pr_sc_Litt3200',
#  '166_1p1_Al_sc_Meditron',
#  '161_1b1_Al_sc_Meditron',
#  '205_4b2_Pl_mc_AKGC417L',
#  '170_1b4_Pr_mc_AKGC417L',
#  '143_1b1_Al_sc_Meditron',
#  '195_1b1_Ar_sc_Litt3200',
#  '181_1b2_Ar_mc_LittC2SE',
#  '204_2b5_Ar_mc_AKGC417L',
#  '113_1b1_Ll_sc_Litt3200',
#  '205_3b4_Pl_mc_AKGC417L',
#  '180_1b4_Ar_mc_AKGC417L',
#  '179_1b1_Al_sc_Meditron',
#  '133_2p4_Ar_mc_AKGC417L',
#  '162_2b4_Lr_mc_AKGC417L',
#  '210_1b1_Ar_sc_Meditron',
#  '154_1b3_Al_mc_AKGC417L',
#  '132_2b2_Lr_mc_LittC2SE',
#  '172_1b5_Al_mc_AKGC417L',
#  '162_2b4_Ar_mc_AKGC417L',
#  '198_6p1_Pr_mc_AKGC417L',
#  '156_2b3_Pr_mc_AKGC417L',
#  '207_2b3_Pr_mc_AKGC417L',
#  '124_1b1_Lr_sc_Litt3200',
#  '170_1b3_Al_mc_AKGC417L',
#  '156_8b3_Ll_mc_AKGC417L',
#  '200_2p4_Lr_mc_AKGC417L',
#  '163_2b2_Pl_mc_AKGC417L',
#  '144_1b1_Al_sc_Meditron',
#  '156_5b3_Lr_mc_AKGC417L',
#  '211_1p2_Pl_mc_AKGC417L',
#  '204_7p5_Ar_mc_AKGC417L']

# %% [markdown]
# We know that our filenames have a certain meaning in them. We get all info (or tokens) by splitting the filename by using "_" as separators. We define a function to do this task.

# %%
def tokenize_file(filename):
    return filename.split('_')

# %% [markdown]
# Now that we have our files list, we have to read each one to get the crackles and wheezes information--including when in the audio file it is recorded (start and end time denoted in seconds).
#
# I've created the files_df to compile all these data (which includes the patient id and acquisition mode--stereo or mono--which will be used later).

# %%
#read each file

files_ = []
for f in files:
    df = pd.read_csv(audio_text_loc + '/' + f + '.txt', sep='\t', names=['start', 'end', 'crackles', 'wheezes'])
    df['filename'] = f
    #get filename features
    f_features = tokenize_file(f)
    df['pId'] = f_features[0]
    df['ac_mode'] = f_features[3]
    
    files_.append(df)
    
files_df = pd.concat(files_)
files_df.reset_index()
files_df.head()
# Out:
#     start     end  crackles  wheezes                filename  pId ac_mode
# 0   1.862   5.718         0        1  160_1b3_Al_mc_AKGC417L  160      mc
# 1   5.718   9.725         1        1  160_1b3_Al_mc_AKGC417L  160      mc
# 2   9.725  13.614         0        1  160_1b3_Al_mc_AKGC417L  160      mc
# 3  13.614  17.671         0        1  160_1b3_Al_mc_AKGC417L  160      mc
# 4  17.671  19.541         0        0  160_1b3_Al_mc_AKGC417L  160      mc

# %% [markdown]
# We want to combine the 2 dataframes we've made so far. However to do that, we have to make sure that the column where we'll combine them must have the same data type.
#
# In this case I just changed the files_df pId column to float64 to be the same as the diagnosis pId dataframe. We can also use int32 to minimise the data allocation in our system however that'll not be our concern for now.
#
# Once the 2 columns have the same data type, we'll use the pandas merge function to combine the 2 dataframes.

# %%
files_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6898 entries, 0 to 6
# Data columns (total 7 columns):
# start       6898 non-null float64
# end         6898 non-null float64
# crackles    6898 non-null int64
# wheezes     6898 non-null int64
# filename    6898 non-null object
# pId         6898 non-null object
# ac_mode     6898 non-null object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 431.1+ KB

# %%
diagnosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 2 columns):
# pId          126 non-null int64
# diagnosis    126 non-null object
# dtypes: int64(1), object(1)
# memory usage: 2.1+ KB

# %%
files_df['pId'] = files_df['pId'].astype('float64')
files_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6898 entries, 0 to 6
# Data columns (total 7 columns):
# start       6898 non-null float64
# end         6898 non-null float64
# crackles    6898 non-null int64
# wheezes     6898 non-null int64
# filename    6898 non-null object
# pId         6898 non-null float64
# ac_mode     6898 non-null object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 431.1+ KB

# %%
files_df = pd.merge(files_df, diagnosis, on='pId')
files_df.head()
# Out:
#     start     end  crackles  wheezes                filename    pId ac_mode  \
# 0   1.862   5.718         0        1  160_1b3_Al_mc_AKGC417L  160.0      mc
# 1   5.718   9.725         1        1  160_1b3_Al_mc_AKGC417L  160.0      mc
# 2   9.725  13.614         0        1  160_1b3_Al_mc_AKGC417L  160.0      mc
# 3  13.614  17.671         0        1  160_1b3_Al_mc_AKGC417L  160.0      mc
# 4  17.671  19.541         0        0  160_1b3_Al_mc_AKGC417L  160.0      mc
#
#   diagnosis
# 0      COPD
# 1      COPD
# 2      COPD
# 3      COPD
# 4      COPD

# %% [markdown]
# We want to slice the wav file into subslices to get the pure breathing part of the audio file. Again, this is denoted by the start and end times mentioned in the txt files.
#
# I've defined the slice_data function to do this.

# %%
#code taken from eatmygoose https://www.kaggle.com/eatmygoose/cnn-detection-of-wheezes-and-crackles
def slice_data(start, end, raw_data,  sample_rate):
    max_ind = len(raw_data) 
    start_ind = min(int(start * sample_rate), max_ind)
    end_ind = min(int(end * sample_rate), max_ind)
    return raw_data[start_ind: end_ind]

# %% [markdown]
# So.. sure we can slice the audio files, but there are things we need to consider as well
# - We need to make sure that they will have the same length (this is in preparation for feeding them into the model for training later)
# - If they're not the same length, then we have to pad the audio with silent (or zeroes) sounds.
# - For the length, we have to know what is the optimal length of time we should use.
#
# For the next part I tried to get the max length per slice that we currently have in our dataframe

# %%
files_df['len_per_slice'] = files_df['end'].sub(files_df['start'], axis = 0) 
max_len_per_slice = max(files_df['len_per_slice'])
max_len_per_slice
# Out:
# 16.163

# %% [markdown]
# 16 seconds long? Is there someone who can have 1 breathe as long as 16 seconds? No, obviously.
#
# So we try and understand our data and check the outliers and the relative maximum of the dataset.

# %%
plt.scatter(files_df['len_per_slice'], y=files_df.index)

# %%
box = plt.boxplot(files_df['len_per_slice'])

# %% [markdown]
# And define the forced maximum length force_max_len as round up of the relative max (5.48 sec round up to 6 sec) length of time.

# %%
force_max_len = math.ceil(boxplot_stats(files_df['len_per_slice'])[0]['whishi'])
force_max_len
# Out:
# 6

# %% [markdown]
# Next is we have to compute the length of the raw data of the slices. I defined a function compute_len to do this.
#
# Remember we had to store the acquisition mode? It's because it has different computation for stereo and mono.
# - Stereo: (Sampling rate * time) * 2
# - Mono: (Sampling rate * time)

# %%
def compute_len(samp_rate=22050, time=force_max_len, acquisition_mode=0):
    '''Computes the supposed length of sliced data
        samp_size = sample size from the data
        samp_rate = sampling rate. by default since we're working on 24-bit files, we'll use 96kHz
        time = length of time for the audio file. by default we'll use the max we have which is 5.48
        acquisition_mode = either mono or stereo. 0 for mono, 1 for stereo
    '''
    comp_len = 0
    if acquisition_mode == 1: #ac mode is single channel which means it's 'mono'
        comp_len = samp_rate * time
    else: #stereo
        comp_len = (samp_rate * time) * 2

    return comp_len

# %% [markdown]
# We're almost ready to create new wav files based on the slices. There's one more problem: we must prepare where to store these new wav files.
#
# So we have to create our output directory and subfolders as defined by the unique diagnosis.

# %%
#create output path
os.makedirs('output')

# %%
for d in ds:
    path = os.path.join('output', d)
    os.makedirs(path)

# %% [markdown]
# Which we can now check using !ls

# %%
# !ls
# Out:
# __notebook__.ipynb  output

# %% [markdown]
# Alright time to roll! Now that everything is set, let's start processing the files now.
#
# The first thing you might notice is the declaration of the i = 0. This will be used in saving of files later. As you may know, each wav file will consist of different slices. When saving these slices, we'll add the ith number of slice. For example, 104_1b1_Ll_sc_Litt3200.wav might have 4 slices, so we'll save them as
# - 104_1b1_Ll_sc_Litt3200_0,
# - 104_1b1_Ll_sc_Litt3200_1,
# - 104_1b1_Ll_sc_Litt3200_2,
# - 104_1b1_Ll_sc_Litt3200_3
#
# Next, for each file
# - get the filename (which will be used for saving later)
# - get the start and end times for the processing of the sliced wav files
# - get the diagnosis so we'll know which subfolder we'll save the sliced wav file
#
# If the slice is greater than force_max_len, force the slice to only be force_max_len long.
#
# Using the librosa function load, load the wav file which returns raw data and the sampling rate.
# Then we feed the raw data to the compute_len function we defined earlier to get the expected length of data.
# Pad the sliced audio with zeroes using the librosa function util.pad_center.
# Then finally, save this file to our destination path which includes which subfolder we'll save it.
#
# TLDR;
# - Read the audio file
# - Slice the audio file
# - Pad in case it's less than 6 sec
# - Save

# %%
i = 0 #iterator for file naming

for idx, row in files_df.iterrows():
    filename = row['filename']
    start = row['start']
    end = row['end']
    diag = row['diagnosis']
    
    #check len and force to 6 sec if more than that
    if force_max_len < end - start:
        end = start + force_max_len
    
    aud_loc = audio_text_loc + '/' + f + '.wav'
    
    if idx != 0:
        if files_df.iloc[idx-1]['filename'] == filename:
            i=i+1
        else:
            i=0
    n_filename = filename + '_' + str(i) + '.wav'
    path = 'output/' + diag + '/' + n_filename
    
    print('processing ' + n_filename + '...')

    data, samplingrate = lb.load(aud_loc)
    sliced_data = slice_data(start=start, end=end, raw_data=data, sample_rate=samplingrate)
    
    #pad audio if < forced_max_len
    a_len = compute_len(samp_rate=samplingrate, acquisition_mode=row['ac_mode']=='sc')
    padded_data = lb.util.pad_center(sliced_data, a_len)

    sf.write(file=path, data=padded_data, samplerate=samplingrate)
# Out:
# processing 160_1b3_Al_mc_AKGC417L_0.wav...
# processing 160_1b3_Al_mc_AKGC417L_1.wav...
# processing 160_1b3_Al_mc_AKGC417L_2.wav...
# processing 160_1b3_Al_mc_AKGC417L_3.wav...
# processing 160_1b3_Al_mc_AKGC417L_4.wav...
# processing 160_1b3_Tc_mc_AKGC417L_0.wav...
# processing 160_1b3_Tc_mc_AKGC417L_1.wav...
# processing 160_1b3_Tc_mc_AKGC417L_2.wav...
# processing 160_1b3_Tc_mc_AKGC417L_3.wav...
# processing 160_1b3_Tc_mc_AKGC417L_4.wav...
# processing 160_1b3_Lr_mc_AKGC417L_0.wav...
# processing 160_1b3_Lr_mc_AKGC417L_1.wav...
# processing 160_1b3_Lr_mc_AKGC417L_2.wav...
# processing 160_1b3_Lr_mc_AKGC417L_3.wav...
# processing 160_1b3_Lr_mc_AKGC417L_4.wav...
# processing 160_1b2_Pr_mc_AKGC417L_0.wav...
# processing 160_1b2_Pr_mc_AKGC417L_1.wav...
# processing 160_2b3_Lr_mc_AKGC417L_0.wav...
# processing 160_2b3_Lr_mc_AKGC417L_1.wav...
# processing 160_2b3_Lr_mc_AKGC417L_2.wav...
# processing 160_2b3_Lr_mc_AKGC417L_3.wav...
# processing 160_2b3_Lr_mc_AKGC417L_4.wav...
# processing 160_2b3_Lr_mc_AKGC417L_5.wav...
# processing 160_2b3_Lr_mc_AKGC417L_6.wav...
# processing 160_1b2_Al_mc_AKGC417L_0.wav...
# processing 160_1b2_Al_mc_AKGC417L_1.wav...
# processing 160_2b4_Ar_mc_AKGC417L_0.wav...
# processing 130_2b2_Ll_mc_AKGC417L_0.wav...
# processing 130_2b2_Ll_mc_AKGC417L_1.wav...
# processing 130_2b2_Ll_mc_AKGC417L_2.wav...
# processing 130_2b2_Ll_mc_AKGC417L_3.wav...
# processing 130_2b2_Ll_mc_AKGC417L_4.wav...
# processing 130_2b2_Ll_mc_AKGC417L_5.wav...
# processing 130_2b2_Ll_mc_AKGC417L_6.wav...
# processing 130_2b2_Ll_mc_AKGC417L_7.wav...
# processing 130_1p4_Tc_mc_AKGC417L_0.wav...
# processing 130_1p4_Tc_mc_AKGC417L_1.wav...
# processing 130_1p4_Tc_mc_AKGC417L_2.wav...
# processing 130_1p4_Tc_mc_AKGC417L_3.wav...
# processing 130_1p4_Tc_mc_AKGC417L_4.wav...
# processing 130_1p4_Tc_mc_AKGC417L_5.wav...
# processing 130_1p4_Tc_mc_AKGC417L_6.wav...
# processing 130_1p4_Tc_mc_AKGC417L_7.wav...
# processing 130_1p3_Pr_mc_AKGC417L_0.wav...
# processing 130_1p3_Pr_mc_AKGC417L_1.wav...
# processing 130_1p3_Pr_mc_AKGC417L_2.wav...
# processing 130_1p3_Pr_mc_AKGC417L_3.wav...
# processing 130_1p3_Pr_mc_AKGC417L_4.wav...
# processing 130_1p3_Pr_mc_AKGC417L_5.wav...
# processing 130_1p2_Ar_mc_AKGC417L_0.wav...
# processing 130_1p2_Ar_mc_AKGC417L_1.wav...
# processing 130_1p2_Ar_mc_AKGC417L_2.wav...
# processing 130_1p2_Ar_mc_AKGC417L_3.wav...
# processing 130_1p2_Ar_mc_AKGC417L_4.wav...
# processing 130_1p2_Ar_mc_AKGC417L_5.wav...
# processing 130_1p2_Ar_mc_AKGC417L_6.wav...
# processing 130_3b4_Lr_mc_AKGC417L_0.wav...
# processing 130_3b4_Lr_mc_AKGC417L_1.wav...
# processing 130_3b4_Lr_mc_AKGC417L_2.wav...
# processing 130_3b4_Lr_mc_AKGC417L_3.wav...
# processing 130_3b4_Lr_mc_AKGC417L_4.wav...
# processing 130_2b3_Ll_mc_AKGC417L_0.wav...
# processing 130_2b3_Ll_mc_AKGC417L_1.wav...
# processing 130_2b3_Ll_mc_AKGC417L_2.wav...
# processing 130_2b3_Ll_mc_AKGC417L_3.wav...
# processing 130_2b3_Ll_mc_AKGC417L_4.wav...
# processing 130_2b3_Ll_mc_AKGC417L_5.wav...
# processing 130_2b3_Ll_mc_AKGC417L_6.wav...
# processing 130_2b3_Ll_mc_AKGC417L_7.wav...
# processing 130_2b3_Ll_mc_AKGC417L_8.wav...
# processing 130_1p4_Lr_mc_AKGC417L_0.wav...
# processing 130_1p4_Lr_mc_AKGC417L_1.wav...
# processing 130_1p4_Lr_mc_AKGC417L_2.wav...
# processing 130_1p4_Lr_mc_AKGC417L_3.wav...
# processing 130_1p4_Lr_mc_AKGC417L_4.wav...
# processing 130_1p4_Lr_mc_AKGC417L_5.wav...
# processing 130_1p4_Lr_mc_AKGC417L_6.wav...
# processing 130_1p4_Pr_mc_AKGC417L_0.wav...
# processing 130_1p4_Pr_mc_AKGC417L_1.wav...
# processing 130_1p4_Pr_mc_AKGC417L_2.wav...
# processing 130_1p4_Pr_mc_AKGC417L_3.wav...
# processing 130_1p4_Pr_mc_AKGC417L_4.wav...
# processing 130_1p4_Pr_mc_AKGC417L_5.wav...
# processing 130_1p4_Pr_mc_AKGC417L_6.wav...
# processing 130_2p5_Tc_mc_AKGC417L_0.wav...
# processing 130_2p5_Tc_mc_AKGC417L_1.wav...
# processing 130_2p5_Tc_mc_AKGC417L_2.wav...
# processing 130_2p5_Tc_mc_AKGC417L_3.wav...
# processing 130_2p5_Tc_mc_AKGC417L_4.wav...
# processing 130_2p5_Tc_mc_AKGC417L_5.wav...
# processing 130_2p5_Tc_mc_AKGC417L_6.wav...
# processing 130_2p5_Tc_mc_AKGC417L_7.wav...
# processing 130_2p5_Tc_mc_AKGC417L_8.wav...
# processing 130_2p5_Tc_mc_AKGC417L_9.wav...
# processing 130_2p5_Tc_mc_AKGC417L_10.wav...
# processing 130_2b4_Ll_mc_AKGC417L_0.wav...
# processing 130_2b4_Ll_mc_AKGC417L_1.wav...
# processing 130_2b4_Ll_mc_AKGC417L_2.wav...
# processing 130_2b4_Ll_mc_AKGC417L_3.wav...
# processing 130_2b4_Ll_mc_AKGC417L_4.wav...
# processing 130_2b4_Ll_mc_AKGC417L_5.wav...
# processing 130_2b4_Ll_mc_AKGC417L_6.wav...
# processing 130_2b4_Ll_mc_AKGC417L_7.wav...
# processing 130_2b4_Ll_mc_AKGC417L_8.wav...
# processing 130_3p4_Tc_mc_AKGC417L_0.wav...
# processing 130_3p4_Tc_mc_AKGC417L_1.wav...
# processing 130_3p4_Tc_mc_AKGC417L_2.wav...
# processing 130_3p4_Tc_mc_AKGC417L_3.wav...
# processing 130_3p4_Tc_mc_AKGC417L_4.wav...
# processing 130_3p4_Tc_mc_AKGC417L_5.wav...
# processing 130_3p4_Tc_mc_AKGC417L_6.wav...
# processing 130_3p4_Tc_mc_AKGC417L_7.wav...
# processing 130_2p5_Ar_mc_AKGC417L_0.wav...
# processing 130_2p5_Ar_mc_AKGC417L_1.wav...
# processing 130_2p5_Ar_mc_AKGC417L_2.wav...
# processing 130_2p5_Ar_mc_AKGC417L_3.wav...
# processing 130_2p5_Ar_mc_AKGC417L_4.wav...
# processing 130_2p5_Ar_mc_AKGC417L_5.wav...
# processing 130_2p5_Ar_mc_AKGC417L_6.wav...
# processing 130_2p5_Ar_mc_AKGC417L_7.wav...
# processing 130_2p5_Ar_mc_AKGC417L_8.wav...
# processing 130_2p5_Ar_mc_AKGC417L_9.wav...
# processing 130_2p5_Ar_mc_AKGC417L_10.wav...
# processing 130_3p4_Al_mc_AKGC417L_0.wav...
# processing 130_3p4_Al_mc_AKGC417L_1.wav...
# processing 130_3p4_Al_mc_AKGC417L_2.wav...
# processing 130_3p4_Al_mc_AKGC417L_3.wav...
# processing 130_3p4_Al_mc_AKGC417L_4.wav...
# processing 130_3p4_Al_mc_AKGC417L_5.wav...
# processing 130_1p3_Tc_mc_AKGC417L_2.wav...
# processing 130_1p3_Tc_mc_AKGC417L_3.wav...
# processing 130_1p3_Tc_mc_AKGC417L_4.wav...
# processing 130_1p3_Tc_mc_AKGC417L_5.wav...
# processing 130_2b2_Lr_mc_AKGC417L_0.wav...
# processing 130_2b2_Lr_mc_AKGC417L_1.wav...
# processing 130_2b2_Lr_mc_AKGC417L_2.wav...
# processing 130_2b2_Lr_mc_AKGC417L_3.wav...
# processing 130_2b2_Lr_mc_AKGC417L_4.wav...
# processing 130_2b2_Lr_mc_AKGC417L_5.wav...
# processing 130_2b2_Lr_mc_AKGC417L_6.wav...
# processing 130_2b2_Lr_mc_AKGC417L_7.wav...
# processing 130_2b2_Ar_mc_AKGC417L_0.wav...
# processing 130_2b2_Ar_mc_AKGC417L_1.wav...
# processing 130_2b2_Ar_mc_AKGC417L_2.wav...
# processing 130_2b2_Ar_mc_AKGC417L_3.wav...
# processing 130_2b2_Ar_mc_AKGC417L_4.wav...
# processing 130_2b2_Ar_mc_AKGC417L_5.wav...
# processing 130_2b2_Ar_mc_AKGC417L_6.wav...
# processing 130_2b2_Ar_mc_AKGC417L_7.wav...
# processing 130_2b3_Pr_mc_AKGC417L_0.wav...
# processing 130_2b3_Pr_mc_AKGC417L_1.wav...
# processing 130_2b3_Pr_mc_AKGC417L_2.wav...
# processing 130_2b3_Pr_mc_AKGC417L_3.wav...
# processing 130_2b3_Pr_mc_AKGC417L_4.wav...
# processing 130_2b3_Pr_mc_AKGC417L_5.wav...
# processing 130_2b3_Pr_mc_AKGC417L_6.wav...
# processing 130_2b3_Pr_mc_AKGC417L_7.wav...
# processing 130_2b3_Pr_mc_AKGC417L_8.wav...
# processing 130_2b4_Pl_mc_AKGC417L_0.wav...
# processing 130_2b4_Pl_mc_AKGC417L_1.wav...
# processing 130_2b4_Pl_mc_AKGC417L_2.wav...
# processing 130_2b4_Pl_mc_AKGC417L_3.wav...
# processing 130_2b4_Pl_mc_AKGC417L_4.wav...
# processing 130_2b4_Pl_mc_AKGC417L_5.wav...
# processing 130_2b4_Pl_mc_AKGC417L_6.wav...
# processing 130_2b4_Pl_mc_AKGC417L_7.wav...
# processing 130_2b4_Pl_mc_AKGC417L_8.wav...
# processing 130_1p3_Lr_mc_AKGC417L_0.wav...
# processing 130_1p3_Lr_mc_AKGC417L_1.wav...
# processing 130_1p3_Lr_mc_AKGC417L_2.wav...
# processing 130_1p3_Lr_mc_AKGC417L_3.wav...
# processing 130_1p3_Lr_mc_AKGC417L_4.wav...
# processing 130_1p3_Lr_mc_AKGC417L_5.wav...
# processing 130_3b4_Pl_mc_AKGC417L_0.wav...
# processing 130_3b4_Pl_mc_AKGC417L_1.wav...
# processing 130_3b4_Pl_mc_AKGC417L_2.wav...
# processing 130_3b4_Pl_mc_AKGC417L_3.wav...
# processing 130_3b4_Pl_mc_AKGC417L_4.wav...
# processing 130_2b4_Ar_mc_AKGC417L_0.wav...
# processing 130_2b4_Ar_mc_AKGC417L_1.wav...
# processing 130_2b4_Ar_mc_AKGC417L_2.wav...
# processing 130_2b4_Ar_mc_AKGC417L_3.wav...
# processing 130_2b4_Ar_mc_AKGC417L_4.wav...
# processing 130_2b4_Ar_mc_AKGC417L_5.wav...
# processing 130_2b4_Ar_mc_AKGC417L_6.wav...
# processing 130_2b4_Ar_mc_AKGC417L_7.wav...
# processing 130_2b4_Ar_mc_AKGC417L_8.wav...
# processing 130_2p5_Lr_mc_AKGC417L_0.wav...
# processing 130_2p5_Lr_mc_AKGC417L_1.wav...
# processing 130_2p5_Lr_mc_AKGC417L_2.wav...
# processing 130_2p5_Lr_mc_AKGC417L_3.wav...
# processing 130_2p5_Lr_mc_AKGC417L_4.wav...
# processing 130_2p5_Lr_mc_AKGC417L_5.wav...
# processing 130_2p5_Lr_mc_AKGC417L_6.wav...
# processing 130_2p5_Lr_mc_AKGC417L_7.wav...
# processing 130_2p5_Lr_mc_AKGC417L_8.wav...
# processing 130_2p5_Lr_mc_AKGC417L_9.wav...
# processing 130_2p5_Lr_mc_AKGC417L_10.wav...
# processing 130_1p2_Al_mc_AKGC417L_0.wav...
# processing 130_1p2_Al_mc_AKGC417L_1.wav...
# processing 130_1p2_Al_mc_AKGC417L_2.wav...
# processing 130_1p2_Al_mc_AKGC417L_3.wav...
# processing 130_1p2_Al_mc_AKGC417L_4.wav...
# processing 130_1p2_Al_mc_AKGC417L_5.wav...
# processing 130_1p2_Al_mc_AKGC417L_6.wav...
# processing 130_3p2_Pr_mc_AKGC417L_0.wav...
# processing 130_3p2_Pr_mc_AKGC417L_1.wav...
# processing 130_3p2_Pr_mc_AKGC417L_2.wav...
# processing 130_3p2_Pr_mc_AKGC417L_3.wav...
# processing 130_3p2_Pr_mc_AKGC417L_4.wav...
# processing 130_3p2_Pr_mc_AKGC417L_5.wav...
# processing 130_3p2_Pr_mc_AKGC417L_6.wav...
# processing 130_1p2_Lr_mc_AKGC417L_0.wav...
# processing 130_1p2_Lr_mc_AKGC417L_1.wav...
# processing 130_1p2_Lr_mc_AKGC417L_2.wav...
# processing 130_1p2_Lr_mc_AKGC417L_3.wav...
# processing 130_1p2_Lr_mc_AKGC417L_4.wav...
# processing 130_1p2_Lr_mc_AKGC417L_5.wav...
# processing 130_1p2_Lr_mc_AKGC417L_6.wav...
# processing 130_3p2_Ar_mc_AKGC417L_0.wav...
# processing 130_3p2_Ar_mc_AKGC417L_1.wav...
# processing 130_3p2_Ar_mc_AKGC417L_2.wav...
# processing 130_3p2_Ar_mc_AKGC417L_3.wav...
# processing 130_3p2_Ar_mc_AKGC417L_4.wav...
# processing 130_3p2_Ar_mc_AKGC417L_5.wav...
# processing 130_3p2_Ar_mc_AKGC417L_6.wav...
# processing 130_3p2_Tc_mc_AKGC417L_0.wav...
# processing 130_3p2_Tc_mc_AKGC417L_1.wav...
# processing 130_3p2_Tc_mc_AKGC417L_2.wav...
# processing 130_3p2_Tc_mc_AKGC417L_3.wav...
# processing 130_3p2_Tc_mc_AKGC417L_4.wav...
# processing 130_3p2_Tc_mc_AKGC417L_5.wav...
# processing 130_3p2_Tc_mc_AKGC417L_6.wav...
# processing 130_2b4_Lr_mc_AKGC417L_0.wav...
# processing 130_2b4_Lr_mc_AKGC417L_1.wav...
# processing 130_2b4_Lr_mc_AKGC417L_2.wav...
# processing 130_2b4_Lr_mc_AKGC417L_3.wav...
# processing 130_2b4_Lr_mc_AKGC417L_4.wav...
# processing 130_2b4_Lr_mc_AKGC417L_5.wav...
# processing 130_2b4_Lr_mc_AKGC417L_6.wav...
# processing 130_2b4_Lr_mc_AKGC417L_7.wav...
# processing 130_2b4_Lr_mc_AKGC417L_8.wav...
# processing 130_2b3_Pl_mc_AKGC417L_0.wav...
# processing 130_2b3_Pl_mc_AKGC417L_1.wav...
# processing 130_2b3_Pl_mc_AKGC417L_2.wav...
# processing 130_2b3_Pl_mc_AKGC417L_3.wav...
# processing 130_2b3_Pl_mc_AKGC417L_4.wav...
# processing 130_2b3_Pl_mc_AKGC417L_5.wav...
# processing 130_2b3_Pl_mc_AKGC417L_6.wav...
# processing 130_2b3_Pl_mc_AKGC417L_7.wav...
# processing 130_2b3_Pl_mc_AKGC417L_8.wav...
# processing 130_2p5_Al_mc_AKGC417L_0.wav...
# processing 130_2p5_Al_mc_AKGC417L_1.wav...
# processing 130_2p5_Al_mc_AKGC417L_2.wav...
# processing 130_2p5_Al_mc_AKGC417L_3.wav...
# processing 130_2p5_Al_mc_AKGC417L_4.wav...
# processing 130_2p5_Al_mc_AKGC417L_5.wav...
# processing 130_2p5_Al_mc_AKGC417L_6.wav...
# processing 130_2p5_Al_mc_AKGC417L_7.wav...
# processing 130_2p5_Al_mc_AKGC417L_8.wav...
# processing 130_2p5_Al_mc_AKGC417L_9.wav...
# processing 130_2p5_Al_mc_AKGC417L_10.wav...
# processing 130_2b2_Pr_mc_AKGC417L_0.wav...
# processing 130_2b2_Pr_mc_AKGC417L_1.wav...
# processing 130_2b2_Pr_mc_AKGC417L_2.wav...
# processing 130_2b2_Pr_mc_AKGC417L_3.wav...
# processing 130_2b2_Pr_mc_AKGC417L_4.wav...
# processing 130_2b2_Pr_mc_AKGC417L_5.wav...
# processing 130_2b2_Pr_mc_AKGC417L_6.wav...
# processing 130_2b2_Pr_mc_AKGC417L_7.wav...
# processing 130_3b4_Pr_mc_AKGC417L_0.wav...
# processing 130_3b4_Pr_mc_AKGC417L_1.wav...
# processing 130_3b4_Pr_mc_AKGC417L_2.wav...
# processing 130_3b4_Pr_mc_AKGC417L_3.wav...
# processing 130_3b4_Pr_mc_AKGC417L_4.wav...
# processing 130_1p2_Ll_mc_AKGC417L_0.wav...
# processing 130_1p2_Ll_mc_AKGC417L_1.wav...
# processing 130_1p2_Ll_mc_AKGC417L_2.wav...
# processing 130_1p2_Ll_mc_AKGC417L_3.wav...
# processing 130_1p2_Ll_mc_AKGC417L_4.wav...
# processing 130_1p2_Ll_mc_AKGC417L_5.wav...
# processing 130_1p2_Ll_mc_AKGC417L_6.wav...
# processing 130_2b2_Pl_mc_AKGC417L_0.wav...
# processing 130_2b2_Pl_mc_AKGC417L_1.wav...
# processing 130_2b2_Pl_mc_AKGC417L_2.wav...
# processing 130_2b2_Pl_mc_AKGC417L_3.wav...
# processing 130_2b2_Pl_mc_AKGC417L_4.wav...
# processing 130_2b2_Pl_mc_AKGC417L_5.wav...
# processing 130_2b2_Pl_mc_AKGC417L_6.wav...
# processing 130_2b2_Pl_mc_AKGC417L_7.wav...
# processing 130_2p5_Pr_mc_AKGC417L_0.wav...
# processing 130_2p5_Pr_mc_AKGC417L_1.wav...
# processing 130_2p5_Pr_mc_AKGC417L_2.wav...
# processing 130_2p5_Pr_mc_AKGC417L_3.wav...
# processing 130_2p5_Pr_mc_AKGC417L_4.wav...
# processing 130_2p5_Pr_mc_AKGC417L_5.wav...
# processing 130_2p5_Pr_mc_AKGC417L_6.wav...
# processing 130_2p5_Pr_mc_AKGC417L_7.wav...
# processing 130_2p5_Pr_mc_AKGC417L_8.wav...
# processing 130_2p5_Pr_mc_AKGC417L_9.wav...
# processing 130_2p5_Pr_mc_AKGC417L_10.wav...
# processing 130_1p4_Ar_mc_AKGC417L_0.wav...
# processing 130_1p4_Ar_mc_AKGC417L_1.wav...
# processing 130_1p4_Ar_mc_AKGC417L_2.wav...
# processing 130_1p4_Ar_mc_AKGC417L_3.wav...
# processing 130_1p4_Ar_mc_AKGC417L_4.wav...
# processing 130_1p4_Ar_mc_AKGC417L_5.wav...
# processing 130_1p4_Ar_mc_AKGC417L_6.wav...
# processing 130_3p2_Al_mc_AKGC417L_0.wav...
# processing 130_3p2_Al_mc_AKGC417L_1.wav...
# processing 130_3p2_Al_mc_AKGC417L_2.wav...
# processing 130_3p2_Al_mc_AKGC417L_3.wav...
# processing 130_3p2_Al_mc_AKGC417L_4.wav...
# processing 130_3p2_Al_mc_AKGC417L_5.wav...
# processing 130_3p2_Al_mc_AKGC417L_6.wav...
# processing 130_1p2_Tc_mc_AKGC417L_0.wav...
# processing 130_1p2_Tc_mc_AKGC417L_1.wav...
# processing 130_1p2_Tc_mc_AKGC417L_2.wav...
# processing 130_1p2_Tc_mc_AKGC417L_3.wav...
# processing 130_1p2_Tc_mc_AKGC417L_4.wav...
# processing 130_1p2_Tc_mc_AKGC417L_5.wav...
# processing 130_1p2_Tc_mc_AKGC417L_6.wav...
# processing 130_2b3_Lr_mc_AKGC417L_0.wav...
# processing 130_2b3_Lr_mc_AKGC417L_1.wav...
# processing 130_2b3_Lr_mc_AKGC417L_2.wav...
# processing 130_2b3_Lr_mc_AKGC417L_3.wav...
# processing 130_2b3_Lr_mc_AKGC417L_4.wav...
# processing 130_2b3_Lr_mc_AKGC417L_5.wav...
# processing 130_2b3_Lr_mc_AKGC417L_6.wav...
# processing 130_2b3_Lr_mc_AKGC417L_7.wav...
# processing 130_2b3_Lr_mc_AKGC417L_8.wav...
# processing 130_2b3_Tc_mc_AKGC417L_0.wav...
# processing 130_2b3_Tc_mc_AKGC417L_1.wav...
# processing 186_2b3_Al_mc_AKGC417L_2.wav...
# processing 186_2b3_Al_mc_AKGC417L_3.wav...
# processing 186_2b3_Al_mc_AKGC417L_4.wav...
# processing 186_3b3_Ar_mc_AKGC417L_0.wav...
# processing 186_3b3_Ar_mc_AKGC417L_1.wav...
# processing 186_3b3_Ar_mc_AKGC417L_2.wav...
# processing 186_3b3_Ar_mc_AKGC417L_3.wav...
# processing 186_3b3_Ar_mc_AKGC417L_4.wav...
# processing 186_3b3_Ar_mc_AKGC417L_5.wav...
# processing 186_2b3_Pl_mc_AKGC417L_0.wav...
# processing 186_2b3_Pl_mc_AKGC417L_1.wav...
# processing 186_2b3_Pl_mc_AKGC417L_2.wav...
# processing 186_2b3_Pl_mc_AKGC417L_3.wav...
# processing 186_2b3_Pl_mc_AKGC417L_4.wav...
# processing 186_3b3_Al_mc_AKGC417L_0.wav...
# processing 186_3b3_Al_mc_AKGC417L_1.wav...
# processing 186_3b3_Al_mc_AKGC417L_2.wav...
# processing 186_3b3_Al_mc_AKGC417L_3.wav...
# processing 186_3b3_Al_mc_AKGC417L_4.wav...
# processing 186_3b3_Al_mc_AKGC417L_5.wav...
# processing 186_3b3_Pr_mc_AKGC417L_0.wav...
# processing 186_3b3_Pr_mc_AKGC417L_1.wav...
# processing 186_3b3_Pr_mc_AKGC417L_2.wav...
# processing 186_3b3_Pr_mc_AKGC417L_3.wav...
# processing 186_3b3_Pr_mc_AKGC417L_4.wav...
# processing 186_3b3_Pr_mc_AKGC417L_5.wav...
# processing 186_2b3_Tc_mc_AKGC417L_0.wav...
# processing 186_2b3_Tc_mc_AKGC417L_1.wav...
# processing 186_2b3_Tc_mc_AKGC417L_2.wav...
# processing 186_2b3_Tc_mc_AKGC417L_3.wav...
# processing 186_2b3_Tc_mc_AKGC417L_4.wav...
# processing 186_3b3_Lr_mc_AKGC417L_0.wav...
# processing 186_3b3_Lr_mc_AKGC417L_1.wav...
# processing 186_3b3_Lr_mc_AKGC417L_2.wav...
# processing 186_3b3_Lr_mc_AKGC417L_3.wav...
# processing 186_3b3_Lr_mc_AKGC417L_4.wav...
# processing 186_3b3_Lr_mc_AKGC417L_5.wav...
# processing 186_2b2_Pr_mc_AKGC417L_0.wav...
# processing 186_2b2_Pr_mc_AKGC417L_1.wav...
# processing 186_2b2_Pr_mc_AKGC417L_2.wav...
# processing 186_2b2_Pr_mc_AKGC417L_3.wav...
# processing 186_2b2_Pr_mc_AKGC417L_4.wav...
# processing 186_2b4_Pl_mc_AKGC417L_0.wav...
# processing 186_2b4_Pl_mc_AKGC417L_1.wav...
# processing 186_2b4_Pl_mc_AKGC417L_2.wav...
# processing 186_2b4_Pl_mc_AKGC417L_3.wav...
# processing 186_2b4_Pl_mc_AKGC417L_4.wav...
# processing 186_3b3_Pl_mc_AKGC417L_0.wav...
# processing 186_3b3_Pl_mc_AKGC417L_1.wav...
# processing 186_3b3_Pl_mc_AKGC417L_2.wav...
# processing 186_3b3_Pl_mc_AKGC417L_3.wav...
# processing 186_3b3_Pl_mc_AKGC417L_4.wav...
# processing 186_3b3_Pl_mc_AKGC417L_5.wav...
# processing 186_2b4_Ar_mc_AKGC417L_0.wav...
# processing 186_2b4_Ar_mc_AKGC417L_1.wav...
# processing 186_2b4_Ar_mc_AKGC417L_2.wav...
# processing 186_2b4_Ar_mc_AKGC417L_3.wav...
# processing 186_2b4_Ar_mc_AKGC417L_4.wav...
# processing 186_2b4_Al_mc_AKGC417L_0.wav...
# processing 186_2b4_Al_mc_AKGC417L_1.wav...
# processing 186_2b4_Al_mc_AKGC417L_2.wav...
# processing 186_2b4_Al_mc_AKGC417L_3.wav...
# processing 186_2b4_Al_mc_AKGC417L_4.wav...
# processing 186_2b2_Pl_mc_AKGC417L_0.wav...
# processing 186_2b2_Pl_mc_AKGC417L_1.wav...
# processing 186_2b2_Pl_mc_AKGC417L_2.wav...
# processing 186_2b2_Pl_mc_AKGC417L_3.wav...
# processing 186_2b2_Pl_mc_AKGC417L_4.wav...
# processing 186_3b3_Tc_mc_AKGC417L_0.wav...
# processing 186_3b3_Tc_mc_AKGC417L_1.wav...
# processing 186_3b3_Tc_mc_AKGC417L_2.wav...
# processing 186_3b3_Tc_mc_AKGC417L_3.wav...
# processing 186_3b3_Tc_mc_AKGC417L_4.wav...
# processing 186_3b3_Tc_mc_AKGC417L_5.wav...
# processing 186_2b3_Lr_mc_AKGC417L_0.wav...
# processing 186_2b3_Lr_mc_AKGC417L_1.wav...
# processing 186_2b3_Lr_mc_AKGC417L_2.wav...
# processing 186_2b3_Lr_mc_AKGC417L_3.wav...
# processing 186_2b3_Lr_mc_AKGC417L_4.wav...
# processing 186_2b2_Al_mc_AKGC417L_0.wav...
# processing 186_2b2_Al_mc_AKGC417L_1.wav...
# processing 186_2b2_Al_mc_AKGC417L_2.wav...
# processing 186_2b2_Al_mc_AKGC417L_3.wav...
# processing 186_2b2_Al_mc_AKGC417L_4.wav...
# processing 186_2b2_Lr_mc_AKGC417L_0.wav...
# processing 186_2b2_Lr_mc_AKGC417L_1.wav...
# processing 186_2b2_Lr_mc_AKGC417L_2.wav...
# processing 186_2b2_Lr_mc_AKGC417L_3.wav...
# processing 186_2b2_Lr_mc_AKGC417L_4.wav...
# processing 186_2b3_Ar_mc_AKGC417L_0.wav...
# processing 186_2b3_Ar_mc_AKGC417L_1.wav...
# processing 186_2b3_Ar_mc_AKGC417L_2.wav...
# processing 186_2b3_Ar_mc_AKGC417L_3.wav...
# processing 186_2b3_Ar_mc_AKGC417L_4.wav...
# processing 186_2b2_Ar_mc_AKGC417L_0.wav...
# processing 186_2b2_Ar_mc_AKGC417L_1.wav...
# processing 186_2b2_Ar_mc_AKGC417L_2.wav...
# processing 186_2b2_Ar_mc_AKGC417L_3.wav...
# processing 186_2b2_Ar_mc_AKGC417L_4.wav...
# processing 186_2b4_Lr_mc_AKGC417L_0.wav...
# processing 186_2b4_Lr_mc_AKGC417L_1.wav...
# processing 186_2b4_Lr_mc_AKGC417L_2.wav...
# processing 178_1b6_Lr_mc_AKGC417L_6.wav...
# processing 178_1b6_Lr_mc_AKGC417L_7.wav...
# processing 178_1b6_Pl_mc_AKGC417L_0.wav...
# processing 178_1b6_Pl_mc_AKGC417L_1.wav...
# processing 178_1b6_Pl_mc_AKGC417L_2.wav...
# processing 178_1b6_Pl_mc_AKGC417L_3.wav...
# processing 178_1b6_Pl_mc_AKGC417L_4.wav...
# processing 178_1b6_Pl_mc_AKGC417L_5.wav...
# processing 178_1b6_Pl_mc_AKGC417L_6.wav...
# processing 178_1b6_Pl_mc_AKGC417L_7.wav...
# processing 158_1p4_Lr_mc_AKGC417L_0.wav...
# processing 158_1p4_Lr_mc_AKGC417L_1.wav...
# processing 158_1p4_Lr_mc_AKGC417L_2.wav...
# processing 158_1p4_Lr_mc_AKGC417L_3.wav...
# processing 158_1p4_Lr_mc_AKGC417L_4.wav...
# processing 158_1p4_Lr_mc_AKGC417L_5.wav...
# processing 158_1p4_Lr_mc_AKGC417L_6.wav...
# processing 158_1p4_Lr_mc_AKGC417L_7.wav...
# processing 158_1p4_Lr_mc_AKGC417L_8.wav...
# processing 158_1p4_Tc_mc_AKGC417L_0.wav...
# processing 158_1p4_Tc_mc_AKGC417L_1.wav...
# processing 158_1p4_Tc_mc_AKGC417L_2.wav...
# processing 158_1p4_Tc_mc_AKGC417L_3.wav...
# processing 158_1p4_Tc_mc_AKGC417L_4.wav...
# processing 158_1p4_Tc_mc_AKGC417L_5.wav...
# processing 158_1p4_Tc_mc_AKGC417L_6.wav...
# processing 158_1p4_Tc_mc_AKGC417L_7.wav...
# processing 158_1p4_Tc_mc_AKGC417L_8.wav...
# processing 158_2p3_Tc_mc_AKGC417L_0.wav...
# processing 158_2p3_Tc_mc_AKGC417L_1.wav...
# processing 158_2p3_Tc_mc_AKGC417L_2.wav...
# processing 158_2p3_Tc_mc_AKGC417L_3.wav...
# processing 158_2p3_Tc_mc_AKGC417L_4.wav...
# processing 158_2p3_Tc_mc_AKGC417L_5.wav...
# processing 158_2p3_Tc_mc_AKGC417L_6.wav...
# processing 158_2p3_Tc_mc_AKGC417L_7.wav...
# processing 158_2p3_Tc_mc_AKGC417L_8.wav...
# processing 158_2p3_Tc_mc_AKGC417L_9.wav...
# processing 158_2p3_Tc_mc_AKGC417L_10.wav...
# processing 158_2p3_Tc_mc_AKGC417L_11.wav...
# processing 158_1p3_Pl_mc_AKGC417L_0.wav...
# processing 158_1p3_Pl_mc_AKGC417L_1.wav...
# processing 158_1p3_Pl_mc_AKGC417L_2.wav...
# processing 158_1p3_Pl_mc_AKGC417L_3.wav...
# processing 158_1p3_Pl_mc_AKGC417L_4.wav...
# processing 158_1p3_Pl_mc_AKGC417L_5.wav...
# processing 158_1p3_Pl_mc_AKGC417L_6.wav...
# processing 158_1p3_Pl_mc_AKGC417L_7.wav...
# processing 158_1p3_Pl_mc_AKGC417L_8.wav...
# processing 158_2p3_Lr_mc_AKGC417L_0.wav...
# processing 158_2p3_Lr_mc_AKGC417L_1.wav...
# processing 158_2p3_Lr_mc_AKGC417L_2.wav...
# processing 158_2p3_Lr_mc_AKGC417L_3.wav...
# processing 158_2p3_Lr_mc_AKGC417L_4.wav...
# processing 158_2p3_Lr_mc_AKGC417L_5.wav...
# processing 158_2p3_Lr_mc_AKGC417L_6.wav...
# processing 158_2p3_Lr_mc_AKGC417L_7.wav...
# processing 158_2p3_Lr_mc_AKGC417L_8.wav...
# processing 158_2p3_Lr_mc_AKGC417L_9.wav...
# processing 158_2p3_Lr_mc_AKGC417L_10.wav...
# processing 158_2p3_Lr_mc_AKGC417L_11.wav...
# ...
# processing 153_1b1_Al_sc_Meditron_5.wav...
# processing 153_1b1_Al_sc_Meditron_6.wav...
# processing 153_1b1_Al_sc_Meditron_7.wav...
# processing 153_1b1_Al_sc_Meditron_8.wav...
# processing 128_1b3_Tc_mc_LittC2SE_0.wav...
# processing 128_1b3_Tc_mc_LittC2SE_1.wav...
# processing 128_1b3_Tc_mc_LittC2SE_2.wav...
# processing 128_1b3_Tc_mc_LittC2SE_3.wav...
# processing 128_1b3_Tc_mc_LittC2SE_4.wav...
# processing 208_1b1_Ll_sc_Meditron_0.wav...
# processing 208_1b1_Ll_sc_Meditron_1.wav...
# processing 208_1b1_Ll_sc_Meditron_2.wav...
# processing 208_1b1_Ll_sc_Meditron_3.wav...
# processing 208_1b1_Ll_sc_Meditron_4.wav...
# processing 208_1b1_Ll_sc_Meditron_5.wav...
# processing 208_1b1_Ll_sc_Meditron_6.wav...
# processing 208_1b1_Ll_sc_Meditron_7.wav...
# processing 208_1b1_Ll_sc_Meditron_8.wav...
# processing 208_1b1_Ll_sc_Meditron_9.wav...
# processing 208_1b1_Ll_sc_Meditron_10.wav...
# processing 208_1b1_Ll_sc_Meditron_11.wav...
# processing 208_1b1_Ll_sc_Meditron_12.wav...
# processing 167_1b1_Pr_sc_Meditron_0.wav...
# processing 167_1b1_Pr_sc_Meditron_1.wav...
# processing 167_1b1_Pr_sc_Meditron_2.wav...
# processing 167_1b1_Pr_sc_Meditron_3.wav...
# processing 167_1b1_Pr_sc_Meditron_4.wav...
# processing 167_1b1_Pr_sc_Meditron_5.wav...
# processing 167_1b1_Pr_sc_Meditron_6.wav...
# processing 167_1b1_Pr_sc_Meditron_7.wav...
# processing 167_1b1_Pr_sc_Meditron_8.wav...
# processing 167_1b1_Pr_sc_Meditron_9.wav...
# processing 167_1b1_Pr_sc_Meditron_10.wav...
# processing 167_1b1_Pr_sc_Meditron_11.wav...
# processing 167_1b1_Pr_sc_Meditron_12.wav...
# processing 167_1b1_Pr_sc_Meditron_13.wav...
# processing 167_1b1_Pr_sc_Meditron_14.wav...
# processing 167_1b1_Al_sc_Meditron_0.wav...
# processing 167_1b1_Al_sc_Meditron_1.wav...
# processing 167_1b1_Al_sc_Meditron_2.wav...
# processing 167_1b1_Al_sc_Meditron_3.wav...
# processing 167_1b1_Al_sc_Meditron_4.wav...
# processing 167_1b1_Al_sc_Meditron_5.wav...
# processing 167_1b1_Al_sc_Meditron_6.wav...
# processing 167_1b1_Al_sc_Meditron_7.wav...
# processing 167_1b1_Al_sc_Meditron_8.wav...
# processing 167_1b1_Al_sc_Meditron_9.wav...
# processing 167_1b1_Al_sc_Meditron_10.wav...
# processing 167_1b1_Al_sc_Meditron_11.wav...
# processing 167_1b1_Al_sc_Meditron_12.wav...
# processing 155_2b1_Al_mc_LittC2SE_0.wav...
# processing 155_2b1_Al_mc_LittC2SE_1.wav...
# processing 155_2b1_Al_mc_LittC2SE_2.wav...
# processing 155_2b1_Al_mc_LittC2SE_3.wav...
# processing 155_2b1_Al_mc_LittC2SE_4.wav...
# processing 155_2b1_Al_mc_LittC2SE_5.wav...
# processing 132_2b1_Lr_mc_LittC2SE_0.wav...
# processing 132_2b1_Lr_mc_LittC2SE_1.wav...
# processing 132_2b1_Lr_mc_LittC2SE_2.wav...
# processing 132_2b1_Lr_mc_LittC2SE_3.wav...
# processing 132_2b1_Lr_mc_LittC2SE_4.wav...
# processing 132_2b1_Lr_mc_LittC2SE_5.wav...
# processing 132_2b1_Lr_mc_LittC2SE_6.wav...
# processing 132_2b1_Lr_mc_LittC2SE_7.wav...
# processing 132_2b1_Lr_mc_LittC2SE_8.wav...
# processing 132_2b2_Lr_mc_LittC2SE_0.wav...
# processing 132_2b2_Lr_mc_LittC2SE_1.wav...
# processing 132_2b2_Lr_mc_LittC2SE_2.wav...
# processing 132_2b2_Lr_mc_LittC2SE_3.wav...
# processing 132_2b2_Lr_mc_LittC2SE_4.wav...
# processing 132_2b2_Lr_mc_LittC2SE_5.wav...
# processing 132_2b2_Lr_mc_LittC2SE_6.wav...
# processing 132_2b2_Lr_mc_LittC2SE_7.wav...
# processing 132_2b2_Lr_mc_LittC2SE_8.wav...
# processing 132_2b2_Lr_mc_LittC2SE_9.wav...
# processing 202_1b1_Ar_sc_Meditron_0.wav...
# processing 202_1b1_Ar_sc_Meditron_1.wav...
# processing 202_1b1_Ar_sc_Meditron_2.wav...
# processing 202_1b1_Ar_sc_Meditron_3.wav...
# processing 202_1b1_Ar_sc_Meditron_4.wav...
# processing 202_1b1_Ar_sc_Meditron_5.wav...
# processing 202_1b1_Ar_sc_Meditron_6.wav...
# processing 202_1b1_Ar_sc_Meditron_7.wav...
# processing 202_1b1_Ar_sc_Meditron_8.wav...
# processing 202_1b1_Ar_sc_Meditron_9.wav...
# processing 217_1b1_Tc_sc_Meditron_0.wav...
# processing 217_1b1_Tc_sc_Meditron_1.wav...
# processing 217_1b1_Tc_sc_Meditron_2.wav...
# processing 217_1b1_Tc_sc_Meditron_3.wav...
# processing 217_1b1_Tc_sc_Meditron_4.wav...
# processing 217_1b1_Tc_sc_Meditron_5.wav...
# processing 217_1b1_Tc_sc_Meditron_6.wav...
# processing 217_1b1_Tc_sc_Meditron_7.wav...
# processing 217_1b1_Tc_sc_Meditron_8.wav...
# processing 217_1b1_Tc_sc_Meditron_9.wav...
# processing 217_1b1_Tc_sc_Meditron_10.wav...
# processing 115_1b1_Ar_sc_Meditron_0.wav...
# processing 115_1b1_Ar_sc_Meditron_1.wav...
# processing 115_1b1_Ar_sc_Meditron_2.wav...
# processing 115_1b1_Ar_sc_Meditron_3.wav...
# processing 115_1b1_Ar_sc_Meditron_4.wav...
# processing 115_1b1_Ar_sc_Meditron_5.wav...
# processing 115_1b1_Ar_sc_Meditron_6.wav...
# processing 115_1b1_Ar_sc_Meditron_7.wav...
# processing 115_1b1_Ar_sc_Meditron_8.wav...
# processing 115_1b1_Ar_sc_Meditron_9.wav...
# processing 115_1b1_Ar_sc_Meditron_10.wav...
# processing 115_1b1_Ar_sc_Meditron_11.wav...
# processing 115_1b1_Ar_sc_Meditron_12.wav...
# processing 115_1b1_Ar_sc_Meditron_13.wav...
# processing 115_1b1_Ar_sc_Meditron_14.wav...
# processing 115_1b1_Ar_sc_Meditron_15.wav...
# processing 115_1b1_Ar_sc_Meditron_16.wav...
# processing 115_1b1_Ar_sc_Meditron_17.wav...
# processing 115_1b1_Ar_sc_Meditron_18.wav...
# processing 115_1b1_Ar_sc_Meditron_19.wav...
# processing 115_1b1_Ar_sc_Meditron_20.wav...
# processing 115_1b1_Ar_sc_Meditron_21.wav...
# processing 115_1b1_Ar_sc_Meditron_22.wav...
# processing 115_1b1_Ar_sc_Meditron_23.wav...
# processing 194_1b1_Pr_sc_Meditron_0.wav...
# processing 194_1b1_Pr_sc_Meditron_1.wav...
# processing 194_1b1_Pr_sc_Meditron_2.wav...
# processing 194_1b1_Pr_sc_Meditron_3.wav...
# processing 194_1b1_Pr_sc_Meditron_4.wav...
# processing 194_1b1_Pr_sc_Meditron_5.wav...
# processing 194_1b1_Pr_sc_Meditron_6.wav...
# processing 194_1b1_Pr_sc_Meditron_7.wav...
# processing 194_1b1_Pr_sc_Meditron_8.wav...
# processing 194_1b1_Lr_sc_Meditron_0.wav...
# processing 194_1b1_Lr_sc_Meditron_1.wav...
# processing 194_1b1_Lr_sc_Meditron_2.wav...
# processing 194_1b1_Lr_sc_Meditron_3.wav...
# processing 194_1b1_Lr_sc_Meditron_4.wav...
# processing 194_1b1_Lr_sc_Meditron_5.wav...
# processing 194_1b1_Lr_sc_Meditron_6.wav...
# processing 194_1b1_Lr_sc_Meditron_7.wav...
# processing 194_1b1_Lr_sc_Meditron_8.wav...
# processing 224_1b1_Tc_sc_Meditron_0.wav...
# processing 224_1b1_Tc_sc_Meditron_1.wav...
# processing 224_1b1_Tc_sc_Meditron_2.wav...
# processing 224_1b1_Tc_sc_Meditron_3.wav...
# processing 224_1b1_Tc_sc_Meditron_4.wav...
# processing 224_1b1_Tc_sc_Meditron_5.wav...
# processing 224_1b1_Tc_sc_Meditron_6.wav...
# processing 224_1b2_Al_sc_Meditron_0.wav...
# processing 224_1b2_Al_sc_Meditron_1.wav...
# processing 224_1b2_Al_sc_Meditron_2.wav...
# processing 224_1b2_Al_sc_Meditron_3.wav...
# processing 224_1b2_Al_sc_Meditron_4.wav...
# processing 224_1b2_Al_sc_Meditron_5.wav...
# processing 148_1b1_Al_sc_Meditron_3.wav...
# processing 148_1b1_Al_sc_Meditron_4.wav...
# processing 148_1b1_Al_sc_Meditron_5.wav...
# processing 148_1b1_Al_sc_Meditron_6.wav...
# processing 148_1b1_Al_sc_Meditron_7.wav...
# processing 148_1b1_Al_sc_Meditron_8.wav...
# processing 148_1b1_Al_sc_Meditron_9.wav...
# processing 148_1b1_Al_sc_Meditron_10.wav...
# processing 189_1b2_Lr_mc_LittC2SE_0.wav...
# processing 189_1b2_Lr_mc_LittC2SE_1.wav...
# processing 189_1b2_Lr_mc_LittC2SE_2.wav...
# processing 189_1b2_Lr_mc_LittC2SE_3.wav...
# processing 189_1b2_Lr_mc_LittC2SE_4.wav...
# processing 102_1b1_Ar_sc_Meditron_0.wav...
# processing 102_1b1_Ar_sc_Meditron_1.wav...
# processing 102_1b1_Ar_sc_Meditron_2.wav...
# processing 102_1b1_Ar_sc_Meditron_3.wav...
# processing 102_1b1_Ar_sc_Meditron_4.wav...
# processing 102_1b1_Ar_sc_Meditron_5.wav...
# processing 102_1b1_Ar_sc_Meditron_6.wav...
# processing 102_1b1_Ar_sc_Meditron_7.wav...
# processing 102_1b1_Ar_sc_Meditron_8.wav...
# processing 102_1b1_Ar_sc_Meditron_9.wav...
# processing 102_1b1_Ar_sc_Meditron_10.wav...
# processing 102_1b1_Ar_sc_Meditron_11.wav...
# processing 102_1b1_Ar_sc_Meditron_12.wav...
# processing 173_1b1_Al_sc_Meditron_0.wav...
# processing 173_1b1_Al_sc_Meditron_1.wav...
# processing 173_1b1_Al_sc_Meditron_2.wav...
# processing 173_1b1_Al_sc_Meditron_3.wav...
# processing 173_1b1_Al_sc_Meditron_4.wav...
# processing 173_1b1_Al_sc_Meditron_5.wav...
# processing 173_1b1_Al_sc_Meditron_6.wav...
# processing 173_1b1_Al_sc_Meditron_7.wav...
# processing 173_1b1_Al_sc_Meditron_8.wav...
# processing 173_1b1_Al_sc_Meditron_9.wav...
# processing 173_1b1_Al_sc_Meditron_10.wav...
# processing 173_1b1_Al_sc_Meditron_11.wav...
# processing 173_1b1_Al_sc_Meditron_12.wav...
# processing 123_1b1_Al_sc_Meditron_0.wav...
# processing 123_1b1_Al_sc_Meditron_1.wav...
# processing 123_1b1_Al_sc_Meditron_2.wav...
# processing 123_1b1_Al_sc_Meditron_3.wav...
# processing 123_1b1_Al_sc_Meditron_4.wav...
# processing 123_1b1_Al_sc_Meditron_5.wav...
# processing 123_1b1_Al_sc_Meditron_6.wav...
# processing 123_1b1_Al_sc_Meditron_7.wav...
# processing 184_1b1_Ar_sc_Meditron_0.wav...
# processing 184_1b1_Ar_sc_Meditron_1.wav...
# processing 184_1b1_Ar_sc_Meditron_2.wav...
# processing 184_1b1_Ar_sc_Meditron_3.wav...
# processing 184_1b1_Ar_sc_Meditron_4.wav...
# processing 184_1b1_Ar_sc_Meditron_5.wav...
# processing 184_1b1_Ar_sc_Meditron_6.wav...
# processing 184_1b1_Ar_sc_Meditron_7.wav...
# processing 169_1b2_Ll_sc_Meditron_0.wav...
# processing 169_1b2_Ll_sc_Meditron_1.wav...
# processing 169_1b2_Ll_sc_Meditron_2.wav...
# processing 169_1b2_Ll_sc_Meditron_3.wav...
# processing 169_1b2_Ll_sc_Meditron_4.wav...
# processing 169_1b2_Ll_sc_Meditron_5.wav...
# processing 169_1b2_Ll_sc_Meditron_6.wav...
# processing 169_1b1_Lr_sc_Meditron_0.wav...
# processing 169_1b1_Lr_sc_Meditron_1.wav...
# processing 169_1b1_Lr_sc_Meditron_2.wav...
# processing 169_1b1_Lr_sc_Meditron_3.wav...
# processing 169_1b1_Lr_sc_Meditron_4.wav...
# processing 169_1b1_Lr_sc_Meditron_5.wav...
# processing 169_1b1_Lr_sc_Meditron_6.wav...
# processing 210_1b1_Al_sc_Meditron_0.wav...
# processing 210_1b1_Al_sc_Meditron_1.wav...
# processing 210_1b1_Al_sc_Meditron_2.wav...
# processing 210_1b1_Al_sc_Meditron_3.wav...
# processing 210_1b1_Al_sc_Meditron_4.wav...
# processing 210_1b1_Al_sc_Meditron_5.wav...
# processing 210_1b1_Al_sc_Meditron_6.wav...
# processing 210_1b1_Al_sc_Meditron_7.wav...
# processing 210_1b1_Al_sc_Meditron_8.wav...
# processing 210_1b1_Al_sc_Meditron_9.wav...
# processing 210_1b1_Al_sc_Meditron_10.wav...
# processing 210_1b1_Al_sc_Meditron_11.wav...
# processing 210_1b1_Al_sc_Meditron_12.wav...
# processing 210_1b1_Al_sc_Meditron_13.wav...
# processing 210_1b1_Al_sc_Meditron_14.wav...
# processing 210_1b1_Al_sc_Meditron_15.wav...
# processing 210_1b1_Al_sc_Meditron_16.wav...
# processing 210_1b1_Al_sc_Meditron_17.wav...
# processing 210_1b1_Ar_sc_Meditron_0.wav...
# processing 210_1b1_Ar_sc_Meditron_1.wav...
# processing 210_1b1_Ar_sc_Meditron_2.wav...
# processing 210_1b1_Ar_sc_Meditron_3.wav...
# processing 210_1b1_Ar_sc_Meditron_4.wav...
# processing 210_1b1_Ar_sc_Meditron_5.wav...
# processing 210_1b1_Ar_sc_Meditron_6.wav...
# processing 210_1b1_Ar_sc_Meditron_7.wav...
# processing 210_1b1_Ar_sc_Meditron_8.wav...
# processing 210_1b1_Ar_sc_Meditron_9.wav...
# processing 210_1b1_Ar_sc_Meditron_10.wav...
# processing 210_1b1_Ar_sc_Meditron_11.wav...
# processing 210_1b1_Ar_sc_Meditron_12.wav...
# processing 136_1b1_Ar_sc_Meditron_0.wav...
# processing 136_1b1_Ar_sc_Meditron_1.wav...
# processing 136_1b1_Ar_sc_Meditron_2.wav...
# processing 136_1b1_Ar_sc_Meditron_3.wav...
# processing 136_1b1_Ar_sc_Meditron_4.wav...
# processing 136_1b1_Ar_sc_Meditron_5.wav...
# processing 136_1b1_Ar_sc_Meditron_6.wav...
# processing 136_1b1_Ar_sc_Meditron_7.wav...
# processing 136_1b1_Ar_sc_Meditron_8.wav...
# processing 161_1b1_Pl_sc_Meditron_0.wav...
# processing 161_1b1_Pl_sc_Meditron_1.wav...
# processing 161_1b1_Pl_sc_Meditron_2.wav...
# processing 161_1b1_Pl_sc_Meditron_3.wav...
# processing 161_1b1_Pl_sc_Meditron_4.wav...
# processing 161_1b1_Pl_sc_Meditron_5.wav...
# processing 161_1b1_Pl_sc_Meditron_6.wav...
# processing 161_1b1_Pl_sc_Meditron_7.wav...
# processing 161_1b1_Pl_sc_Meditron_8.wav...
# processing 161_1b1_Pl_sc_Meditron_9.wav...
# processing 161_1b1_Al_sc_Meditron_0.wav...
# processing 161_1b1_Al_sc_Meditron_1.wav...
# processing 161_1b1_Al_sc_Meditron_2.wav...
# processing 161_1b1_Al_sc_Meditron_3.wav...
# processing 161_1b1_Al_sc_Meditron_4.wav...
# processing 161_1b1_Al_sc_Meditron_5.wav...
# processing 161_1b1_Al_sc_Meditron_6.wav...
# processing 161_1b1_Al_sc_Meditron_7.wav...
# processing 161_1b1_Al_sc_Meditron_8.wav...
# processing 187_1b1_Ll_sc_Meditron_0.wav...
# processing 187_1b1_Ll_sc_Meditron_1.wav...
# processing 187_1b1_Ll_sc_Meditron_2.wav...
# processing 187_1b1_Ll_sc_Meditron_3.wav...
# processing 187_1b1_Ll_sc_Meditron_4.wav...
# processing 187_1b1_Ll_sc_Meditron_5.wav...
# processing 187_1b1_Ll_sc_Meditron_6.wav...
# processing 187_1b1_Ll_sc_Meditron_7.wav...
# processing 187_1b1_Ll_sc_Meditron_8.wav...
# processing 187_1b1_Ll_sc_Meditron_9.wav...
# processing 187_1b1_Ll_sc_Meditron_10.wav...
# processing 187_1b1_Ll_sc_Meditron_11.wav...
# processing 187_1b1_Ll_sc_Meditron_12.wav...
# processing 187_1b1_Ll_sc_Meditron_13.wav...
# processing 187_1b1_Ll_sc_Meditron_14.wav...
# processing 187_1b1_Ll_sc_Meditron_15.wav...
# processing 187_1b1_Ll_sc_Meditron_16.wav...
# processing 143_1b1_Al_sc_Meditron_0.wav...
# processing 143_1b1_Al_sc_Meditron_1.wav...
# processing 143_1b1_Al_sc_Meditron_2.wav...
# processing 143_1b1_Al_sc_Meditron_3.wav...
# processing 143_1b1_Al_sc_Meditron_4.wav...
# processing 143_1b1_Al_sc_Meditron_5.wav...
# processing 143_1b1_Al_sc_Meditron_6.wav...
# processing 143_1b1_Al_sc_Meditron_7.wav...
# processing 143_1b1_Al_sc_Meditron_8.wav...
# processing 143_1b1_Al_sc_Meditron_9.wav...
# processing 143_1b1_Al_sc_Meditron_10.wav...
# processing 143_1b1_Al_sc_Meditron_11.wav...
# processing 143_1b1_Al_sc_Meditron_12.wav...
# processing 143_1b1_Al_sc_Meditron_13.wav...
# processing 143_1b1_Al_sc_Meditron_14.wav...
# processing 143_1b1_Al_sc_Meditron_15.wav...
# processing 143_1b1_Al_sc_Meditron_16.wav...
# processing 143_1b1_Al_sc_Meditron_17.wav...

# %% [markdown]
# Then it's done! We can check using !ls again

# %%
# !ls output/
# Out:
# Asthma	Bronchiectasis	Bronchiolitis  COPD  Healthy  LRTI  Pneumonia  URTI
